# %% [markdown]
# ## Data Science for Good: City of Los Angeles

# %% [markdown]
# ![](https://media.giphy.com/media/3XAU2dw8fjghZmsRZd/giphy.gif)

# %% [markdown]
# ### Problem statement

# %% [markdown]
# The goal is to convert a folder full of plain-text job postings into a single structured CSV file and then to use this data to:
# 1.  identify language that can negatively bias the pool of applicants;
# 2.  improve the diversity and quality of the applicant pool; and/or
# 3.  make it easier to determine which promotions are available to employees in each job class.

# %%
from wand.image import Image as Img
Img(filename='../input/cityofla/CityofLA/Additional data/PDFs/2017/july 2017/July 21/ARTS ASSOCIATE 2454 072117 REV 072817.pdf', resolution=300)
# Out:
# <wand.image.Image: 00951c6 'PDF' (2550x3300)>

# %% [markdown]
# ## What is in this kernel?

# %% [markdown]
# 0. [Getting basic idea](#0)
# 1. [Data Preparation](#1)
# 2. [Exploratory data analysis](#2)
#     1. [Suggestions ](#3)
# 3. [Finding and removing word biases](#4)
# 4. [Clustering jobs ](#5)
# 5. [Readability Index](#6)

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import os
import numpy as np
from datetime import datetime
from collections  import Counter
from nltk import word_tokenize
import seaborn as sns
import matplotlib.pyplot as plt
import calendar
from wordcloud import WordCloud ,STOPWORDS
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
print(os.listdir("../input"))
from gensim.models import word2vec
from sklearn.manifold import TSNE
from nltk import pos_tag
from nltk.help import upenn_tagset
import gensim
import matplotlib.colors as mcolors
from nltk import jaccard_distance
from nltk import ngrams
#import textstat
plt.style.use('ggplot')
# Out:
# ['cityofla']

# %% [markdown]
# ### checking all subdirectories

# %%
files=[dir for dir in os.walk('../input/cityofla')]
for file in files:
    print(os.listdir(file[0]))
    print("\n")
# Out:
# ['CityofLA']
#
#
# ['Additional data', 'Job Bulletins']
#
#
# ['job bulletins with annotations', 'job_titles.csv', 'PDFs', 'Description of promotions in job bulletins.docx', 'City Job Paths', 'kaggle_data_dictionary.csv', 'sample job class export template.csv']
#
#
# ['Annotation elements with description.docx', 'systems_analyst.pdf', 'tree_surgeon.pdf', 'carpenter.pdf']
#
#
# ['2014', '2015', '2018', '2016', '2017']
#
#
# ['September 2014', 'May 2014', 'november 2014', 'June 2014', 'january 2014', 'october 2014', 'February 2014', 'December 2014', 'march 2014', 'April 2014', 'July 2014']
#
#
# ['09262014']
#
#
# ['Thumbs.db', 'CHIEF INSPECTOR 4254.pdf', 'PRINCIPAL INSPECTOR 4226.pdf']
#
#
# ['050214', '050914', '052314', '053014', '051614', '050714 rev']
#
#
# ['Thumbs.db', 'AQUARIST 2400.pdf', 'Job summaries 050214.pdf', 'STEAM PLANT MAINTENANCE SUPERVISOR 3786.pdf']
#
#
# ['Thumbs.db', 'POLICE SERGEANT 2227.pdf', 'Job summaries 05092014.pdf', 'PRINCIPAL CITY PLANNER 7946.pdf', 'SENIOR COMMERCIAL FIELD REPRESENTATIVE 1602.pdf']
#
#
# ['PRINCIPAL CITY PLANNER 7946 rev.pdf', 'Thumbs.db', 'Job Summaries 05222014.pdf', 'RETIREMENT PLAN MANAGER 9149.pdf', 'COMMUNICATIONS ELECTRICIAN SUPERVISOR 3689.pdf']
#
#
# ['Thumbs.db', 'Job summaries 05302014.pdf', 'SECURITY OFFICER 3181.pdf', 'ART CENTER DIRECTOR 2478.pdf', 'ASSISTANT COMMUNICATIONS CABLE WORKER 3808.pdf', 'GRAPHICS SUPERVISOR 7935.pdf']
#
#
# ['WATERWORKS MECHANIC SUPERVISOR 3987.pdf', 'Thumbs.db', 'WHARFINGER 1190 051614.pdf', 'Job summaries 05152014.pdf', 'DIRECTOR OF SECURITY SERVICES 3208.pdf']
#
#
# ['Thumbs.db', 'CHIEF TAX COMPLIANCE OFFICER 1211 rev043014.pdf']
#
#
# ['11212014', '11072014', '11142014', '11282014']
#
#
# ['Job summaries 11212014.pdf', 'Thumbs.db', 'RISK AND INSURANCE ASSISTANT 1645.pdf', 'WATER SERVICE REPRESENTATIVE 1693.pdf']
#
#
# ['GARDENER CARETAKER 3141.pdf', 'TREE SURGEON SUPERVISOR 3117.pdf', 'Thumbs.db', 'SENIOR ELECTRIC SERVICE REPRESENTATIVE 7521.pdf', 'Job summaries 11072014.pdf', 'BOILERMAKER 3735.pdf', 'STEAM PLANT OPERATOR 5624.pdf']
#
#
# ['ELECTRIC DISTRIBUTION MECHANIC 3879 REV 111214.pdf', 'Senior Transportation Investigator 4273.pdf', 'Thumbs.db', 'Community Affairs Advocate 2496.pdf', 'Supervising Occupational Health Nurse 2315.pdf', 'Procurement Supervisor 1852.pdf', 'Land Surveying Assistant 7283.pdf', 'Job Summaries 111414.pdf', 'ADVANCE PRACTICE PROVIDER CORRECTIONAL CARE 2325 REV 111214.pdf', 'Real Estate Trainee 1937.pdf']
#
#
# ['DEPARTMENTAL CHIEF ACCOUNTANT 1593.pdf', 'ENGINEERING DESIGNER 7217.pdf', 'Thumbs.db', 'WATER UTILITY OPERATOR SUPERVISOR 5857.pdf', 'AQUEDUCT AND RESERVOIR KEEPER 5813.pdf', 'Job summaries 11282014.pdf', 'STEAM PLANT ASSISTANT 5622.pdf']
#
#
# ['060614', 'Job 06272014.doc', '062014', '061314', '062414']
#
#
# ['ELECTRICAL REPAIR SUPERVISOR 3855.pdf', 'Job summaries 06062014.pdf', 'Thumbs.db', 'MARINE ENVIRONMENTAL MANAGER 9437.pdf', 'FIRE PROTECTION ENGINEERING ASSOCIATE 7978.pdf', 'ARCHIVIST 1191.pdf', 'CUSTOMER SERVICE SPECIALIST 1229.pdf']
#
#
# ['PUBLIC INFORMATION DIRECTOR 1800 0.pdf', 'AUDIO VISUAL TECHNICIAN 6147.pdf', 'BUILDING REPAIR SUPERVISOR 3338.pdf', 'Thumbs.db', 'SIGNAL SYSTEMS ELECTRICIAN 3819.pdf', 'HOUSING INSPECTOR 4243.pdf', 'CHIEF MANAGEMENT ANALYST 9182.pdf', 'CARPET LAYER 3418.pdf', 'FINANCIAL MANAGER 1157.pdf']
#
#
# ['Thumbs.db', 'SHEET METAL SUPERVISOR 3777.pdf', 'ELECTRICIAN 3863.pdf', 'Job summaries 06132014.pdf', 'EMERGENCY MANAGEMENT COORDINATOR 1702.pdf', 'TELECOMMUNICATIONS PLANNING AND UTILIZATION OFFICER 7640.pdf', 'SENIOR COMMUNICATIONS ENGINEER 7614.pdf', 'SENIOR LOAD DISPATCHER 5235.pdf']
#
#
# ['SENIOR STREET LIGHTING ENGINEER 9536.pdf', 'Thumbs.db', 'Job Summaries 06272014.pdf', 'SENIOR COMMUNICATIONS ELECTRICIAN 3638.pdf', 'ENGINEER OF FIRE DEPEPARTMENT  2131.pdf', 'INFORMATION SYSTEMS MANAGER 1409.pdf', 'STREET LIGHTING ELECTRICIAN SUPERVISOR 3840.pdf', 'POLICE SERVICE REPRESENTATIVE 2207.pdf', 'STREET LIGHTING ENGINEER 7537.pdf']
#
#
# ['01312014', '01092014', 'Thumbs.db', '01242014', '01032014']
#
#
# ['ENGINEERING GEOLOGIST 7255.pdf', 'SENIOR WINDOW CLEANER 3174.pdf', 'PERSONNEL ANALYST 1731.pdf', 'Thumbs.db', 'UTILITY ACCOUNTANT 1511.pdf', 'ELECTRIC SERVICE REPRESENTATIVE 7520.pdf', 'Job Summaries 01312014.pdf']
#
#
# ['INTERNAL AUDITOR 1625.pdf', 'Thumbs.db', 'Job Summaries 01092014.pdf']
#
#
# ['Thumbs.db', 'GEOGRAPHIC INFORMATION SYSTEMS SPECIALIST 7213.pdf', 'SENIOR CLAIMS REPRESENTATIVE  1770.pdf', 'HEAVY DUTY TRUCK OPERATOR 3584.pdf', 'Job summaries 01232014.pdf']
#
#
# ['Thumbs.db']
#
#
# ['101714', '103114', '102414', '101014']
#
#
# ['BOILERMAKER SUPERVISOR 3737.pdf', 'SENIOR CARPENTER  3345.pdf', 'Thumbs.db', 'INDUSTRIAL HYGIENIST 2330.pdf', 'Job Summaries 10172014.pdf']
#
#
# ['AVIONICS SPECIALIST 3565.pdf', 'Thumbs.db', 'CHIEF TRANSPORTATION INVESTIGATOR 4275.pdf', 'SECRETARY 1116.pdf', 'ASPHALT PLANT OPERATOR 4143 REV.pdf', 'MECHANICAL ENGINEER 7558.pdf', 'Job Summaries 10312014.pdf']
#
#
# ['ASPHALT PLANT OPERATOR 4143.pdf', 'PRINCIPAL ACCOUNTANT 1525.pdf', 'Thumbs.db', 'Job Summaries 10242014.pdf', 'TIRE REPAIRER 3727.pdf', 'SENIOR TAX AUDITOR 1519.pdf']
#
#
# ['SENIOR PAINTER 3424.pdf', 'PLANNING ASSISTANT 7939.pdf', 'Thumbs.db', 'WATER UTILITY WORKER 3912 Rev 101014.pdf', 'Job Summaries 10102014.pdf', 'FIRE INSPECTOR 2128.pdf', 'BUILDING CIVIL ENGINEER 7244.pdf']
#
#
# ['02142014', '02072014', '02272014', '02212014']
#
#
# ['Job summaries 02142014.pdf', 'AIRPORT MANAGER 7260.pdf', 'Thumbs.db', 'SENIOR HEAVY DUTY EQUIPMENT MECHANIC 3745.pdf', 'CONTROL SYSTEMS ENGINEERING ASSOCIATE 7230.pdf']
#
#
# ['Thumbs.db', 'Job Summaries 02072014.pdf', 'TRAFFIC PAINTER AND SIGN POSTER 3421.pdf', 'INDUSTRIAL CHEMIST 7834.pdf', 'PARKING MANAGER 9170.pdf']
#
#
# ['Job summaries 02262014.pdf', 'Thumbs.db', 'SHEET METAL WORKER 3775.pdf', 'SENIOR ELECTRICAL TESTER 7515.pdf', 'SAFETY ENGINEER ELEVATORS 4263.pdf']
#
#
# ['Job Summaries 02192014.pdf', 'Thumbs.db', 'PROPERTY MANAGER 1964.pdf']
#
#
# ['121914', '120514', '121214', '122614']
#
#
# ['BUILDING REPAIRER 3333.pdf', 'SENIOR STRUCTURAL ENGINEER 9425.pdf', 'EQUIPMENT SUPERINTENDENT 3750.pdf', 'Thumbs.db', 'SENIOR PERSONNEL ANALYST 9167.pdf', 'ELECTRIC TROUBLE DISPATCHER 3828.pdf', 'COMMUNICATIONS ENGINEERING ASSOCIATE 7607.pdf', 'Job summaries 12182014.pdf', 'COMMERCIAL FIELD SUPERVISOR 1603.pdf']
#
#
# ['COMMUNICATIONS INFORMATION REPRESENTATIVE 1461.pdf', 'Thumbs.db', 'Job summaries 12052014.pdf', 'SENIOR PARK SERVICES ATTENDANT 2422.pdf', 'PAINTER SUPERVISOR 3426.pdf']
#
#
# ['STREET TREE SUPERINTENDENT 3160.pdf', 'SIGN PAINTER 3428.pdf', 'ROOFER 3476.pdf', 'SPECIAL INVESTIGATOR 0602.pdf', 'Thumbs.db', 'Job summaries12122014.pdf']
#
#
# ['COMMUNICATIONS ENGINEER 7610.pdf', 'Thumbs.db', 'Job summaries 12262014.pdf', 'SENIOR CONSTRUCTION INSPECTOR 7294.pdf']
#
#
# ['03072014', '03212014', '03282014', '03142014']
#
#
# ['SENIOR HYDROGRAPHER 7264.pdf', 'Thumbs.db', 'FIELD ENGINEERING AIDE 7228.pdf', 'Job Summaries 03042014.pdf']
#
#
# ['PRINCIPAL PUBLIC RELATIONS REPRESENTATIVE 1786.pdf', 'Thumbs.db', 'DETENTION OFFICER 3211.pdf', 'SENIOR BUILDING MECHANICAL INSPECTOR 4253.pdf', 'Job summaries 03212014.pdf']
#
#
# ['PRINCIPAL DEPUTY CONTROLLER.pdf', 'PUBLIC RELATIONS SPECIALIST.pdf', 'Thumbs.db', 'SENIOR PLUMBING INSPECTOR.pdf', 'UTILITY ADMINISTRATOR.pdf', 'SENIOR UTILITY ACCOUNTANT.pdf', 'SUPPLY SERVICES MANAGER.pdf', 'Job Summaries 03272014.pdf']
#
#
# ['Thumbs.db', 'SENIOR SYSTEMS ANALYST 1597.pdf', 'COMMUNICATIONS CABLE WORKER 3802.pdf', 'Job Summaries 03122014.pdf', 'EQUIPMENT REPAIR SUPERVISOR 3746.pdf']
#
#
# ['041114', 'Thumbs.db', '040414', '040814 revised', '042514', '041814']
#
#
# ['EQUIPMENT OPERATOR 3525.pdf', "WORKERS' COMPENSATION CLAIMS ASSISTANT 1775.pdf", 'Job summaries 04102014.pdf', 'Thumbs.db', 'removed', 'CHIEF FINANCIAL OFFICER 9230.pdf', 'ARTS ASSOCIATE 2454.pdf', 'SENIOR PLUMBING INSPECTOR 4233 rev041014.pdf', 'TREE SURGEON 3114.pdf']
#
#
# ['Thumbs.db', 'DIRECTOR OF FIELD OPERATIONS 4321.pdf']
#
#
# ['PORT POLICE SERGEANT 3222.pdf', 'TRUCK AND EQUIPMENT DISPATCHER 3586.pdf', 'Thumbs.db']
#
#
# ['Thumbs.db', 'PRINCIPAL DEPUTY CONTROLLER 9653 032814 Rev 040814.pdf']
#
#
# ['WELDER 3796.pdf', 'Thumbs.db', 'Job summaries 04252014.pdf', 'SENIOR CONSTRUCTION ENGINEER 7289.pdf', 'LICENSED VOCATIONAL NURSE  2332.pdf', 'UTILITY EXECUTIVE SECRETARY 1336.pdf', 'TAX COMPLIANCE OFFICER 1179.pdf']
#
#
# ['UTILITY BUYER 1861.pdf', 'Thumbs.db', '311 DIRECTOR  9206.pdf', 'DIRECTOR OF FIELD OPERATIONS 4321.pdf', 'CHIEF TAX COMPLIANCE OFFICER 1211.pdf', 'Job summaries 04182014.pdf', 'SENIOR COMMUNICATIONS CABLE WORKER 3801.pdf']
#
#
# ['071114', '072514', 'Thumbs.db', 'Job 07112014.doc', '071714', '070414', 'UTILITY SERVICES MANAGER 9106 rev.pdf']
#
#
# ['Thumbs.db', 'FIREFIGHTER 2112.pdf', 'Job Summaries 07112014.pdf', 'WASTEWATER TREATMENT MECHANIC SUPERVISOR 5617.pdf', 'MARINE ENVIRONMENTAL SUPERVISOR 9433.pdf', 'DATA PROCESSING TECHNICIAN 1136.pdf', 'ELEVATOR MECHANIC 3866.pdf', 'DIRECTOR OF HOUSING 1568.pdf']
#
#
# ['GRAPHICS DESIGNER 1670.pdf', 'PRINCIPAL ENVIRONMENTAL ENGINEER 7875.pdf', 'SENIOR GARDENER 3143.pdf', 'PRINCIPAL COMMUNICATIONS OPERATOR 1458.pdf', 'Thumbs.db', 'UNDERGROUND DISTRIBUTION CONSTRUCTION MECHANIC 3812.pdf', 'INSTRUMENT MECHANIC SUPERVISOR 3844.pdf', 'COMMERCIAL SERVICE SUPERVISOR  1213.pdf', 'BUILDING MAINTENANCE DISTRICT SUPERVISOR 3190.pdf', 'WATER MICROBIOLOGIST  7857.pdf', 'INSTRUMENT MECHANIC 3843.pdf', 'WASTEWATER TREATMENT LABORATORY MANAGER 7840.pdf', 'COMMERCIAL FIELD REPRESENTATIVE 1600.pdf', 'UNDERGROUND DISTRIBUTION CONSTRUCTION SUPERVISOR 3814.pdf', 'ARTS MANAGER  2455.pdf', 'CHEMIST 7833.pdf', 'ASSISTANT DEPUTY SUPERINTENDENT OF BUILDING 4219.pdf', 'WATER UTILITY WORKER 3912.pdf', 'UTILITY SERVICES SPECIALIST 3755.pdf', "SENIOR WORKERS' COMPENSATION ANALYST 1769.pdf", 'ELECTRIC STATION OPERATOR  5224.pdf']
#
#
# ['ELEVATOR MECHANIC HELPER 3860.pdf', 'PIPEFITTER 3433.pdf', 'PRINCIPAL WORKERS_ COMPENSATION ANALYST 1777.pdf', 'AIR CONDITIONING MECHANIC 3774.pdf', 'Thumbs.db', 'ARCHITECT 7925.pdf', 'SENIOR ELECTRICAL MECHANIC SUPERVISOR 3836.pdf', 'SENIOR UNDERGROUND DISTRIBUTION CONSTRUCTION SUPERVISOR 3815.pdf', 'ANIMAL CARE TECHNICIAN 4310.pdf', 'WORKERS_ COMPENSATION ANALYST 1774.pdf', 'GEOGRAPHIC INFORMATION SYSTEMS SUPERVISOR 7214.pdf', 'SMS PAYMENT CLERK 1214.pdf', 'LEGISLATIVE REPRESENTATIVE 9482.pdf', 'Job Summaries 07182014.pdf']
#
#
# ['WASTEWATER TREATMENT OPERATOR 4123.pdf', 'Thumbs.db', 'UTILITY SERVICES MANAGER 9106.pdf', 'CONSTRUCTION INSPECTOR 7291.pdf', 'Job Summaries 07042014.pdf']
#
#
# ['March 2015', 'november 2015', 'september 2015', 'february 2015', 'october 2015', 'July 2015', 'May 2015', 'august 2015', 'June 2015', 'december 2015', 'January 2015', 'april 2015']
#
#
# ['03202015', '03272015', '03062015', '03132015']
#
#
# ['PRINCIPAL UTILITY ACCOUNTANT 1589.pdf', 'SENIOR TRANSPORTATION ENGINEER 9262.pdf', 'Thumbs.db', 'ELECTRICAL INSPECTOR 4221.pdf', 'PRINCIPAL UTILITY ACCOUNTANT 1589_Revised.pdf', 'CHIEF OF OPERATIONS 7258.pdf', 'Job Summaries 03202015.pdf']
#
#
# ['STAFF ASSISTANT TO GENERAL MANAGER WATER AND POWER 9185.pdf', 'Thumbs.db', 'PRINCIPAL LIBRARIAN 6155.pdf', 'CHIEF SECURITY OFFICER 3187.pdf', 'MANAGEMENT ASSISTANT 1539.pdf', 'REHABILITATION PROJECT COORDINATOR 8502.pdf', 'OPERATIONS AND STATISTICAL RESEARCH ANALYST 1779.pdf', 'MOTOR SWEEPER OPERATOR 3585 rev032515.pdf', 'SENIOR CUSTODIAN 3157.pdf', 'Job summaries 03272015.pdf']
#
#
# ['AUTO BODY BUILDER AND REPAIRER 3704.pdf', 'PERSONNEL RECORDS SUPERVISOR 1129.pdf', 'Job Summaries 03062015.pdf', 'SENIOR PORT ELECTRICAL MECHANIC 3847.pdf', 'Thumbs.db', 'MOTOR SWEEPER OPERATOR 3585.pdf', 'SIGN SHOP SUPERVISOR 3419.pdf']
#
#
# ['Thumbs.db', 'DIVISION LIBRARIAN 6157.pdf', 'FINANCIAL DEVELOPMENT OFFICER 1571.pdf', 'APPARATUS OPERATOR 2121.pdf', 'HEAD CUSTODIAN SUPERVISOR  3178.pdf', 'CHIEF CONSTRUCTION INSPECTOR 7296.pdf', 'POLICE ADMINISTRATOR 9196.pdf', 'Job Summaries 03132015.pdf', 'POLYGRAPH EXAMINER 2240 REV031015.pdf']
#
#
# ['Thumbs.db', 'AQUEDUCT AND RESERVOIR SUPERVISOR 5816.pdf', 'Job Summaries 09112015.pdf', 'ELECTRICAL ENGINEERING DRAFTING TECHNICIAN 7532.pdf', 'SAFETY ENGINEERING ASSOCIATE 1726.pdf', 'SENIOR REAL ESTATE OFFICER 1961.pdf', 'PLUMBER 3443.pdf', 'PRINCIPAL CIVIL ENGINEER 9489.pdf']
#
#
# ['Job summaries 09182015.pdf', 'WATER UTILITY SUPERVISOR 3976.pdf', 'LANDSCAPE ARCHITECT 7929.pdf', 'SENIOR PARK RANGER 1967.pdf', 'Thumbs.db', 'LEGISLATIVE ASSISTANT 1182.pdf', 'CONSTRUCTION EQUIPMENT SERVICE WORKER 3541.pdf']
#
#
# ['02272015', '02132015', '02062015', '02202015']
#
#
# ['Thumbs.db', 'ENVIRONMETAL COMPLIANCE INSPECTOR 4292.pdf', 'Job Summaries 02272015.pdf', 'TRAFFIC MARKING AND SIGN SUPERINTENDENT 3430.pdf', 'POLYGRAPH EXAMINER 2240.pdf', 'SENIOR SAFETY ENGINEER PRESSURE VESSELS 4262 REVISED.pdf', 'POLYGRAPH EXAMINER 2240 rev030215.pdf', 'PLUMBING INSPECTOR 4231.pdf']
#
#
# ['SENIOR DATA PROCESSING TECHNICIAN 1139.pdf', 'Thumbs.db', 'POLICE PERFORMANCE AUDITOR 1627 rev 020615 (1).pdf', 'PORT PILOT 5151 REVISED 021215.pdf', 'Job Summaries 02132015.pdf', 'SENIOR CONSTRUCTION ESTIMATOR 3347 rev 020615.pdf', 'PRINCIPAL CLERK 1201.pdf', 'SENIOR SAFETY ENGINEER PRESSURE VESSELS 4262.pdf', 'AIRPORT ENGINEER 7256 rev021015.pdf']
#
#
# ['SENIOR CONSTRUCTION ESTIMATOR 3347.pdf', 'SIGN PAINTER 3428.pdf', 'AIRPORT GUIDE 0845 REV.pdf', 'Thumbs.db', 'IRRIGATION SPECIALIST 3913.pdf', 'Job Summaries 02062015.pdf', 'POLICE PERFORMANCE AUDITOR 1627.pdf', 'POLICE PERFORMANCE AUDITOR 1627 rev 020615.pdf']
#
#
# ['SENIOR AUDITOR 1518.pdf', 'SENIOR FIRE STATISTICAL ANALYST 1639.pdf', 'Thumbs.db', 'HOUSING PLANNING AND ECONOMIC ANALYST 8504.pdf', 'DUPLICATING MACHINE OPERATOR 1493.pdf', 'Job Summaries 02202015.pdf', 'SENIOR DETENTION OFFICER 3212.pdf']
#
#
# ['oct 9', 'STREET LIGHTING ELECTRICIAN 3811 Revised 101515.pdf', 'oct 30', 'ZOO REGISTRAR 4290 REV 100815.pdf', 'MECHANICAL ENGINEERING ASSOCIATE 7554 CAMPUS REV 010215.pdf', 'PRINCIPAL TAX COMPLIANCE OFFICER 1195 REV 102815.pdf', 'oct 23', 'Thumbs.db', 'oct 16', 'HARBOR PLANNING AND RESEARCH DIRECTOR 9234 REVISED 100715.pdf', 'oct 2', 'IMPROVEMENT ASSESSOR SUPERVISOR 1564 Revised 101515.pdf', 'COMMUNICATIONS ELECTRICIAN 3686 092515 rev.pdf', 'POLYGRAPH EXAMINER 2240 REV 100715.pdf']
#
#
# ['SENIOR STOREKEEPER 1837.pdf', 'PERSONNEL DIRECTOR 1714.pdf', 'Thumbs.db', 'ADMINISTRATIVE HEARING EXAMINER 9135.pdf', 'OFFICE ENGINEERING TECHNICIAN 7212.pdf', 'TRANSPORTATION ENGINEERING AIDE 7285.pdf', 'Job summaries 10092015.pdf', 'CRIME AND INTELLIGENCE ANALYST  2236.pdf', 'TAX AUDITOR 1514.pdf', 'ADMINISTRATIVE CLERK 1358.pdf', 'CABLE TELEVISION PRODUCTION MANAGER 1801.pdf', '~$IME AND INTELLIGENCE ANALYST  2236 100915 (1).doc']
#
#
# ['CEMENT FINISHER WORKER 3351.pdf', 'WASTEWATER TREATMENT OPERATOR 4123.pdf', 'Thumbs.db', 'JOB SUMMARIES 10302015.pdf', 'SENIOR ANIMAL CONTROL OFFICER 4316.pdf', 'WORKERS_ COMPENSATION ANALYST 1774.pdf', 'ZOO CURATOR OF EDUCATION 4300.pdf']
#
#
# ['ASSISTANT STREET LIGHTING ELECTRICIAN 3809.pdf', 'SENIOR CIVIL ENGINEERING DRAFTING TECHNICIAN 7207.pdf', 'FIREBOAT PILOT 5127.pdf', 'Thumbs.db', 'FIREBOAT MATE 5125.pdf', 'Job summaries 10232015.pdf', 'STREET SERVICES INVESTIGATOR 4283.pdf']
#
#
# ['Thumbs.db', 'ENGINEER OF SURVEYS 9486.pdf', 'CORRECTIONAL NURSE 2317.pdf', 'Job Summaries 10162015.pdf', 'UTILITIES SERVICE INVESTIGATOR 1631.pdf', 'SENIOR ELECTRICAL ENGINEERING DRAFTING TECHNICIAN 7209.pdf', 'STRUCTURAL ENGINEER 7956.pdf', 'SAFETY ADMINISTRATOR 1728.pdf', 'PRINCIPAL TAX COMPLIANCE OFFICER 1195.pdf']
#
#
# ['DATABASE ARCHITECT 1470.pdf', 'RIDESHARE PROGRAM ADMINISTRATOR 2485.pdf', 'Thumbs.db', 'DETENTION OFFICER 3211.pdf', 'STREET LIGHTING ELECTRICIAN 3811.pdf', 'GEOTECHNICAL ENGINEER 7239.pdf', 'EXECUTIVE ADMINISTRATIVE ASSISTANT 1117.pdf', 'Job summaries 10022015.pdf', 'IMPROVEMENT ASSESSOR SUPERVISOR 1564.pdf', 'ACCOUNTING RECORDS SUPERVISOR 1119.pdf']
#
#
# ['Jul 10', 'jul 17', 'jul 31', 'jul 24', 'Jul 3']
#
#
# ['Thumbs.db', 'ACCOUNTANT 1513.pdf', 'Job Summaries 07102015.pdf', 'SENIOR CIVIL ENGINEER 9485.pdf', 'POLICE OFFICER 2214 Rev 070615.pdf', 'ARCHITECTURAL ASSOCIATE 7926.pdf']
#
#
# ['Job Summaries 07172015.pdf', 'PRINCIPAL PROPERTY OFFICER 3210.pdf', 'EQUIPMENT MECHANIC  3711.pdf', 'Thumbs.db']
#
#
# ['POLICE COMMANDER 2251.pdf', 'Job Summaries 07312015.pdf', 'DIRECTOR OF ENFORCEMENT OPERATIONS 4266.pdf', 'Thumbs.db', 'SIGNAL SYSTEMS SUPERVISOR 3839.pdf', 'SENIOR COMMUNICATIONS ELECTRICIAN SUPERVISOR 3691.pdf', 'ANIMAL KEEPER 4304.pdf', 'AIRPORTS MAINTENANCE SUPERINTENDENT 3331.pdf', 'PRINCIPAL PROPERTY OFFICER 3210 071715 REV.pdf', 'ASSISTANT SIGNAL SYSTEMS ELECTRICIAN 3818.pdf']
#
#
# ['Job summaries 07242015.pdf', 'ELECTRICAL CRAFT HELPER 3799.pdf', 'CITY PLANNER 7944.pdf', 'SHIFT SUPERINTENDENT WASTEWATER TREATMENT 7242.pdf', 'Thumbs.db', 'CIVIL ENGINEER 7237.pdf', 'TRANSPORTATION PLANNING ASSOCIATE 2480.pdf', 'TRANSPORTATION ENGINEERING ASSOCIATE 7280.pdf', 'PROGRAMMER ANALYST 1431.pdf']
#
#
# ['Thumbs.db', 'Job Summaries 07032015.pdf', 'SENIOR INDUSTRIAL HYGIENIST 2331.pdf']
#
#
# ['Thumbs.db', 'may22', 'may8', 'may 1', 'may29', 'may15']
#
#
# ['SENIOR FORENSIC PRINT SPECIALIST 2201 Revised.pdf', 'ENVIRONMENTAL AFFAIRS OFFICER 7320.pdf', 'POWER ENGINEERING MANAGER 9453.pdf', 'Thumbs.db', 'POLICE SURVEILLANCE SPECIALIST 3687.pdf', 'AUTO ELECTRICIAN 3707.pdf', 'MAINTENANCE AND CONSTRUCTION HELPER 3115.pdf', 'Job summaries 05222015.pdf', 'INDUSTRIAL AND COMMERCIAL FINANCE OFFICER 9191 rev051515.pdf']
#
#
# ['Thumbs.db', 'Job summaries 05082015.pdf', 'PRINCIPAL TRANSPORTATION ENGINEER 9266.pdf', 'SENIOR FORENSIC PRINT SPECIALIST 2201.pdf']
#
#
# ['BUILDING CONSTRUCTION AND MAINTENANCE 3124.pdf', 'CHIEF COMMUNICATIONS OPERATOR 1466.pdf', 'Thumbs.db', 'PRINCIPAL CONSTRUCTION INSPECTOR 7297.pdf', 'Job Summaries 05012015.pdf']
#
#
# ['Thumbs.db', 'FINGERPRINT IDENTIFICATION EXPERT 1157.pdf', 'CHIEF INTERNAL AUDITOR 1619.pdf', 'Job summaries 05292015.pdf', 'SENIOR HOUSING INSPECTOR 4244.pdf', 'ELECTRICAL ENGINEERING ASSOCIATE 7525.pdf', 'AQUATIC FACILITY MANAGER 2423.pdf']
#
#
# ['POLICE LIEUTENANT 2232.pdf', 'SENIOR POLICE SERVICE REPRESENTATIVE 2209.pdf', 'CHIEF AIRPORTS ENGINEER 7274.pdf', 'INDUSTRIAL AND COMMERCIAL FINANCE OFFICER 9191.pdf', 'Thumbs.db', 'Job Summaries 05152015.pdf', 'SENIOR MANAGEMENT ANALYST 9171.pdf', 'AUTO BODY REPAIR SUPERVISOR 3706.pdf']
#
#
# ['Thumbs.db', 'aug 7', 'FIRE HELICOPTER PILOT 3563 REV 081815.pdf', 'aug 21', 'ANIMAL CARE TECHNICIAN SUPERVISOR 4313 REV 082715.pdf', 'aug 14', 'aug 28']
#
#
# ['PAYROLL SUPERVISOR 1170.pdf', 'Thumbs.db', 'METER READER 1611.pdf', 'STREET SERVICES WORKER 4150.pdf', 'Job summaries 08072015.pdf', 'TITLE EXAMINER 1943.pdf', 'ENVIRONMENTAL SUPERVISOR 7304.pdf', 'SHIFT SUPERINTENDENT WASTEWATER TREATMENT 7242 REV080515.pdf']
#
#
# ['MECHANICAL ENGINEERING ASSOCIATE 7554.pdf', 'Thumbs.db', 'Job Summaries 08212015.pdf', 'PROTECTIVE COATING WORKER 3463.pdf', 'BUILDING OPERATING ENGINEER 5923.pdf', 'SENIOR ELECTRICAL INSPECTOR 4223.pdf', 'PERSONNEL RESEARCH ANALYST 1739.pdf']
#
#
# ['PRINCIPAL MECHANICAL ENGINEERING DRAFTING TECHNICIAN 7550.pdf', 'SENIOR COMMUNICATIONS ELECTRICIAN SUPERVISOR 3691 rev081115.pdf', 'ANIMAL CARE TECHNICIAN SUPERVISOR 4313.pdf', 'CUSTODIAN SUPERVISOR 3176.pdf', 'Thumbs.db', 'FIRE HELICOPTER PILOT 3563.pdf', 'PARK RANGER 1966.pdf', 'Job Summaries 08142015.pdf', 'DIRECTOR OF ENFORCEMENT OPERATIONS 4266 Rev.pdf']
#
#
# ['STREET SERVICES SUPERVISOR 4152.pdf', 'PRINCIPAL CLERK UTILITY 1202.pdf', 'Job Summaries 08282015.pdf', 'Thumbs.db', 'BUILDING INSPECTOR 4211.pdf', 'LOCKSMITH 3393.pdf', 'BUILDING MECHANICAL INSPECTOR 4251.pdf']
#
#
# ['SANITATION SOLID RESOURCES MANAGER 4126 rev061115.pdf', 'jun 12', 'TAX COMPLIANCE AIDE 1173 rev.pdf', 'jun 26', 'jun 1', 'jun 19', 'jun 5']
#
#
# ['ASSOCIATE ZONING ADMINISTRATOR 7998.pdf', 'CHIEF INTERNAL AUDITOR 1619 REVISED 061015.pdf', 'Thumbs.db', 'AQUATIC FACILITY MANAGER 2423 REVISED 060915.pdf', 'Job Summaries 06122015.pdf', 'CHIEF CLERK POLICE 1219.pdf', 'TAX COMPLIANCE AIDE 1173.pdf']
#
#
# ['PRINCIPAL SECURITY OFFICER 3200.pdf', 'Thumbs.db', 'PROCUREMENT ANALYST 1859.pdf', 'FIRE ASSISTANT CHIEF 2166.pdf', 'Job Summaries 06262015.pdf', 'REAL ESTATE OFFICER 1960.pdf', 'ANIMAL CONTROL OFFICER  4311.pdf']
#
#
# ['PORT POLICE OFFICER 3221 Rev.pdf', 'Thumbs.db', 'POLICE OFFICER 2214 Rev.pdf', 'AIRPORT POLICE OFFICER 3225 Rev.pdf', 'ENVIRONMENTAL AFFAIRS OFFICER 7320 Revised.pdf', 'POLICE SPECIALIST 2217 Rev.pdf']
#
#
# ['DIRECTOR OF POLICE TRANSPORTATION 3722.pdf', 'Thumbs.db', 'GENERAL AUTOMOTIVE SUPERVISOR 3718.pdf', 'CARPENTER 3344.pdf', 'CHIEF ENVIRONMENTAL COMPLIANCE INSPECTOR 4289.pdf', 'Job Summaries 06192015.pdf', 'STREET SERVICES SUPERINTENDENT 4158.pdf', 'LINE MAINTENANCE ASSISTANT 3882.pdf', 'CARPET LAYER 3418.pdf']
#
#
# ['SENIOR SURVEY SUPERVISOR 7288.pdf', 'SANITATION SOLID RESOURCES MANAGER 4126.pdf', 'SENIOR CITY PLANNER 7974.pdf', 'WASTEWATER TREATMENT OPERATOR 4123.pdf', 'Thumbs.db', 'TRANSPORTATION ENGINEER 7278.pdf', 'WASTEWATER TREATMENT ELECTRICIAN SUPERVISOR 5613.pdf', 'SENIOR COMPUTER OPERATOR 1428.pdf', 'Job Summaries 06052015.pdf']
#
#
# ['dec 11', 'Thumbs.db', 'dec 4', 'SAFETY ENGINEER ELEVATORS 4263 REV 120215.pdf', 'dec 18', 'MACHINIST SUPERVISOR 3766 121815 REV 123115 (1).pdf']
#
#
# ['SENIOR EQUIPMENT MECHANIC 3712.pdf', 'Job summaries 12092015.pdf', 'Thumbs.db', 'PLUMBER SUPERVISOR 3446.pdf', 'AIRPORT INFORMATION SPECIALIST 1783.pdf', 'SENIOR HEATING AND REFRIGERATION INSPECTOR 4247.pdf', 'HEATING AND REFRIGERATION INSPECTOR 4245.pdf', 'GOLF STARTER 2453.pdf', 'STEAM PLANT OPERATING SUPERVISOR  5625.pdf', 'CHIEF ELECTRIC PLANT OPERATOR 5237.pdf']
#
#
# ['EXAMINER OF QUESTIONED DOCUMENTS 3229.pdf', 'AIRPORT CHIEF INFORMATION SECURITY OFFICER 1404.pdf', 'PLANNING ASSISTANT 7939.pdf', 'MATERIALS TESTING TECHNICIAN 7968.pdf', 'STORES SUPERVISOR 1866.pdf']
#
#
# ['Thumbs.db', 'FIREFIGHTER 2112.pdf', 'FIRE BATTALION CHIEF 2152.pdf', 'SENIOR ENVIRONMENTAL ENGINEER 7874.pdf', 'AIRPORT SUPERINTENDENT OF OPERATIONS 7268.pdf', 'Job summaries 12182015.pdf', 'PRINCIPAL CLERK POLICE 1152.pdf', 'LABOR SUPERVISOR 3126.pdf', 'MACHINIST SUPERVISOR 3766.pdf', 'SENIOR UTILITY SERVICES SPECIALIST 3753.pdf']
#
#
# ['012315', '010215', '013015', '011615', '010915']
#
#
# ['FORENSIC  PRINT SPECIALIST 2200.pdf', 'APPLICATIONS PROGRAMMER 1429.pdf', 'Thumbs.db', 'HEAVY DUTY EQUIPMENT MECHANIC 3743.pdf', 'Job summaries 01232015.pdf', 'GOLF STARTER SUPERVISOR 2479.pdf']
#
#
# ['Thumbs.db', 'SYSTEMS ANALYST 1596.pdf', 'LICENSED VOCATIONAL NURSE  2332 REV 010215.pdf', 'ELECTRICAL ENGINEERING ASSOCIATE 7525 REV 010215.pdf', 'STRUCTURAL ENGINEERING ASSOCIATE 7957 REV 010215.pdf', 'MECHANICAL ENGINEERING ASSOCIATE 7554 REV 010215.pdf', 'TRANSPORTATION ENGINEERING ASSOCIATE 7280 REV 010215.pdf', 'PORT POLICE OFFICER 3221 Rev 010115.pdf', 'TAX AUDITOR 1514 REV 010215.pdf', 'CIVIL ENGINEERING ASSOCIATE 7246 101102 REV 010215.pdf', 'SENIOR ACCOUNTANT 1523.pdf', 'AIRPORT POLICE OFFICER 3225 Rev 010115.pdf', 'ARCHITECTURAL ASSOCIATE 7926 REV 010215 (1).pdf', 'STREET LIGHTING ENGINEERING ASSOCIATE 7527 REV 010215.pdf', 'POLICE OFFICER 2214 Rev 010115.pdf', 'ENVIRONMENTAL ENGINEERING ASSOCIATE  7871 rev010215.pdf', 'Job Summaries 01022015.pdf', 'POLICE SPECIALIST 2217 Rev 010115.pdf']
#
#
# ['GARAGE ATTENDANT 3531.pdf', 'Thumbs.db', 'Job summaries 01302015.pdf', 'PORT PILOT 5151.pdf', 'CEMENT FINISHER 3353.pdf', 'AIRPORT GUIDE 0845.pdf', 'AIRPORT ENGINEER 7256.pdf']
#
#
# ['SENIOR BUILDING OPERATING ENGINEER 5925.pdf', 'Thumbs.db', 'Job summaries 01162015.pdf']
#
#
# ['SENIOR TRAFFIC SUPERVISOR 3218.pdf', 'Job Summaries 01082015.pdf', 'Thumbs.db']
#
#
# ['apr 10', 'apr 3', 'apr 24', 'apr 17']
#
#
# ['PRINCIPAL DETENTION OFFICER 3215.pdf', 'Thumbs.db', 'DELIVERY DRIVER 1121.pdf', 'CHIEF CUSTODIAN SUPERVISOR 3182.pdf', 'TRUCK OPERATOR 3583.pdf', 'Job summaries 04102015.pdf', 'SENIOR LIBRARIAN 6153.pdf', 'STREET LIGHTING CONSTRUCTION AND MAINTENANCE SUPERINTENDNET 3820.pdf', 'PROPERTY OFFICER 3207.pdf', 'ASSISTANT DIRECTOR INFORMATION SYSTEMS 9377.pdf']
#
#
# ['SENIOR TRANSPORTATION ENGINEER 9262 Revised 040115.pdf', 'Thumbs.db', 'DIVISION LIBRARIAN 6157 rev040115.pdf', 'Job summaries 04032015.pdf']
#
#
# ['Thumbs.db', 'CIVIL ENGINEERING ASSOCIATE 7246.pdf', 'LICENSED VOCATIONAL NURSE  2332.pdf', 'STRUCTURAL ENGINEERING ASSOCIATE 7957.pdf', 'PARK SERVICES ATTENDANT 2412.pdf', 'AIRPORTS MAINTENANCE SUPERVISOR 3336.pdf']
#
#
# ['DIVISION LIBRARIAN 6157 rev041315.pdf', 'Thumbs.db', 'PRINCIPAL LIBRARIAN 6155 rev041315.pdf', 'Job summaries 04172015.pdf', 'LIBRARIAN 6152.pdf', 'UPHOLSTERER 3723.pdf', 'WATER UTILITY WORKER 3912 Rev 041315.pdf']
#
#
# ['June', 'May', 'April', 'December', 'July', 'October', 'November', 'August', 'February', 'March', 'September', 'January']
#
#
# ['Jun 15', 'Jun 1', 'Jun 22', 'Jun 8', 'Jun 27']
#
#
# ['ENVIRONMENTAL AFFAIRS OFFICER 7320 061518.pdf', 'ANIMAL CONTROL OFFICER  4311 061518.pdf', 'INVESTMENT OFFICER 9146 061518.pdf', 'Job 061518 Summary.pdf']
#
#
# ['SENIOR LOAD DISPATCHER 5235 060118.pdf', 'Job 060118 Summary.pdf', 'SENIOR ELECTRICAL REPAIR SUPERVISOR 3856 060118.pdf', 'ADMINISTRATIVE ANALYST 1590 060118.pdf']
#
#
#
#
# ['Job 040618 Summary.pdf', 'WATER SERVICE WORKER 3931 040618 (1).pdf', 'SENIOR MANAGEMENT ANALYST 9171 040618.pdf', 'DIRECTOR OF FIELD OPERATIONS 4321 040618.pdf']
#
#
# ['Job 041318 Summary.pdf', 'SENIOR COMMUNICATIONS ELECTRICIAN SUPERVISOR 3691 041318.pdf', 'SENIOR REAL ESTATE OFFICER 1961 0413018.pdf', 'SENIOR PAINTER 3424 041318.pdf', 'EQUIPMENT SUPERVISOR 3527 041318.pdf', 'PERSONNEL RECORDS SUPERVISOR 1129 041318.pdf', 'FIRE PROTECTION ENGINEERING ASSOCIATE 7978 041318.pdf', 'SENIOR CONSTRUCTION ESTIMATOR 3347 041318.pdf']
#
#
# ['Dec 7', 'Dec 14']
#
#
# ['COMMERCIAL FIELD REPRESENTATIVE 1600 120718.pdf', 'HARBOR ENGINEER 9279 120718.pdf', 'SENIOR PERSONNEL ANALYST 9167 120718.pdf', 'Job 12072018 Summary.pdf', 'WASTEWATER TREATMENT OPERATOR 120718.pdf', 'CITY PLANNER 7944 120718.pdf']
#
#
# ['SENIOR SECURITY OFFICER 3184 121418.pdf', 'WATER UTILITY SUPERINTENDENT 3980 121418.pdf', 'MECHANICAL ENGINEERING DRAFTING TECHNICIAN 7551 121418.pdf', 'DUPLICATING MACHINE OPERATOR 1493 121418.pdf', 'CABLE TELEVISION PRODUCTION MANAGER 1801 121418.pdf', 'Job 12142018 Summary.pdf', 'UNDERGROUND DISTRIBUTION CONSTRUCTION SUPERVISOR 3814 121418.pdf']
#
#
# ['Jul 20', 'Jul 27', 'Jul 6', 'Jul 13']
#
#
# ['WATER TREATMENT SUPERVISOR 5887 072018.pdf', 'Job 072018 Summary.pdf', 'PARK SERVICES SUPERVISOR 2426 072018.pdf', 'COMMUNITY HOUSING PROGRAMS MANAGER 8500 072018.pdf', 'TRANSPORTATION PLANNING ASSOCIATE 2480 072018.pdf', 'POLICE SPECIAL INVESTIGATOR 1640 072018.pdf']
#
#
# ['Job 072718 Summary.pdf', 'PARK RANGER 1966 072718.pdf', 'PRINCIPAL STOREKEEPER 1839 072718.pdf', 'REHABILITATION CONSTRUCTION SPECIALIST 072718.pdf', 'RISK AND INSURANCE ASSISTANT 1645 072718.pdf', 'ACCOUNTING RECORDS SUPERVISOR 1119 072718.pdf']
#
#
# ['PRINCIPAL ANIMAL KEEPER 4312 070618.pdf', 'ZOO REGISTRAR 4290 070618.pdf', 'HOUSING INSPECTOR 4243 070618.pdf', 'AIRPORT ENGINEER 7256 070618.pdf', 'SENIOR ADMINISTRATIVE ANALYST 1541 070618.pdf']
#
#
# ['ACCOUNTING CLERK 1223 071318.pdf', 'Job 071318 Summary.pdf']
#
#
# ['Oct 5', 'Oct 26', 'Oct 19', 'Oct 12']
#
#
# ['PLUMBER SUPERVISOR 3446 100518.pdf', 'ASBESTOS WORKER 3435 100518.pdf', 'Job 10052018 Summary.pdf', 'PRINCIPAL CLERK UTILITY 1202 100518.pdf', 'GARDENER CARETAKER 3141 100518.pdf']
# ['GRAPHICS DESIGNER 1670 011218.pdf', 'FIRE ASSISTANT CHIEF 2166 011218.pdf', 'Job  0112018  Summary.pdf', 'CARPENTER 3344 011218.pdf']
#
#
# ['BENEFITS SPECIALIST 1203 011918.pdf', 'MASONRY WORKER 3451 011918.pdf', 'FIREFIGHTER 2112 011918.pdf', 'Job  0119018  Summary.pdf', 'INTERNAL AUDITOR 1625 011918.pdf']
#
#
# ['Job  01042018  Summary.pdf', 'SENIOR EQUIPMENT MECHANIC 3712 010518.pdf']
#
#
# ['DIRECTOR OF ENFORCEMENT OPERATIONS 4266 012618.pdf', 'INDUSTRIAL HYGIENIST 2330 012618.pdf', 'TRUCK OPERATOR 3583 012618.pdf', 'CONSTRUCTION EQUIPMENT SERVICE WORKER 3541  012618.pdf', 'ASSISTANT AIRPORT MANAGER 7259 012618.pdf', 'SENIOR CIVIL ENGINEER 9485 012618.pdf', 'SENIOR PROPERTY OFFICER 3209 012618.pdf', 'SUPERINTENDENT OF RECREATION AND PARKS OPERATIONS 2472 012618.pdf']
#
#
# ['july 2016', 'May 2016', 'January 2016', 'august 2016', 'December 2016', 'june 2016', 'February 2016', 'November 2016', 'september 2016', 'April 2016', 'October 2016', 'march 2016']
#
#
# ['ELECTRIC DISTRIBUTION MECHANIC 3879 REV072716.pdf', 'Thumbs.db', 'CONSTRUCTION ESTIMATOR 3341 REVISED 072116.pdf', 'jul 22', 'jul 29', 'SYSTEMS AIDE 1599 REVISED 071416.pdf', 'PORT POLICE OFFICER 3221 Rev 072116.pdf', 'jul 15', 'jul 01', 'BUILDING ELECTRICAL ENGINEER 7543 REV 071816.pdf', 'CHIEF ADMINISTRATIVE ANALYST 1554 rev 070716.pdf', 'WATERWORKS ENGINEER 7248 REV 071816.pdf', 'TRANSMISSION AND DISTRIBUTION DISTRICT SUPERVISOR 3875 REVISED 070716.pdf', 'jul 08', 'POWER SHOVEL OPERATOR 3558 REV 070716.pdf', 'ART CURATOR 2448 REV 072816.pdf']
#
#
# ['SENIOR EXAMINER OF QUESTIONED DOCUMENTS 3231.pdf', 'Job Summaries 07222016.pdf', 'Thumbs.db', 'SUPERVISING TRANSPORTATION PLANNER 2481.pdf', 'ELECTRICAL MECHANIC SUPERVISOR 3835.pdf', 'LANDSCAPE ARCHITECTURAL ASSOCIATE  7933.pdf']
#
#
# ['SENIOR PORT ELECTRICAL MECHANIC 3847 072916.pdf', 'Thumbs.db', 'WATER UTILITY SUPERINTENDENT 3980 072916.pdf', 'TREE SURGEON 3114 072916 (1).pdf']
#
#
# ['ART CURATOR 2448.pdf', 'BUILDING ELECTRICAL ENGINEER 7543.pdf', 'Job Summaries 07152016.pdf', 'APPRENTICE MACHINIST 3764.pdf', 'WATERWORKS ENGINEER 7248.pdf']
#
#
# ['Thumbs.db', 'FINANCIAL MANAGER 1557.pdf', 'Job Summaries 07012016.pdf', 'SYSTEMS AIDE 1599.pdf', 'SUPPLY SERVICES MANAGER 1865.pdf']
#
#
# ['Thumbs.db', 'Job Summaries 07082016.pdf', 'CONSTRUCTION ESTIMATOR 3341.pdf', 'APPRENTICE - METAL TRADES 3789.pdf']
#
#
# ['UTILITY BUYER 1861 REV 051916.pdf', 'SENIOR ENVIRONMENTAL COMPLIANCE INSPECTOR 4293 REV 051916.pdf', 'STREET SERVICES GENERAL SUPERINTENDENT 4160 REV 051216.pdf', 'Thumbs.db', 'POLICE SERVICE REPRESENTATIVE 2207 REV 051716.pdf', 'SENIOR MACHINIST SUPERVISOR 3768 051016 rev.pdf', 'may 13', 'may 20', 'may 6', 'SENIOR MACHINIST SUPERVISOR 3768 REV 051616.pdf', 'may 27', 'ASSISTANT RETIREMENT PLAN MANAGER 9415 REV 051216.pdf', 'UTILITY ACCOUNTANT 1511 campus only.pdf', 'SENIOR ENVIRONMENTAL COMPLIANCE INSPECTOR 4293 REV 051216.pdf', 'SENIOR ENVIRONMENTAL COMPLIANCE INSPECTOR 4293 REV 050616.pdf', 'UTILITY BUYER 1861 REV 052616.pdf']
#
#
# ['ART INSTRUCTOR 2447.pdf', 'POLICE SPECIAL INVESTIGATOR 1640.pdf', 'ELECTRICAL MECHANIC 3841.pdf', 'Thumbs.db', 'Job Summaries 05132016.pdf', 'POLICE SERVICE REPRESENTATIVE 2207.pdf', 'CARPENTER SUPERVISOR 3346.pdf']
#
#
# ['PORT MAINTENANCE SUPERVISOR 3128.pdf', 'Thumbs.db', 'Job Summaries 05202016.pdf']
#
#
# ['UTILITY BUYER 1861.pdf', 'Thumbs.db', 'Job Summaries 05062016.pdf', 'ASSISTANT RETIREMENT PLAN MANAGER 9415.pdf']
#
#
# ['Thumbs.db', 'Job summaries 05272016.pdf', 'REAL ESTATE ASSOCIATE 1941.pdf', 'PROPERTY MANAGER 1964.pdf']
#
#
# ['MECHANICAL ENGINEERING DRAFTING TECHNICIAN 7551 rev012216.pdf', 'SENIOR UTILITY BUYER 1862 REV 012816.pdf', 'jan 8', 'Thumbs.db', 'SHOPS SUPERINTENDENT 3780 rev012116.pdf', 'SENIOR ELECTRICAL REPAIR SUPERVISOR 3856 REV 012516.pdf', 'jan 15', 'SENIOR ELECTRICAL REPAIR SUPERVISOR 3856 rev012216.pdf', 'PORT POLICE OFFICER 3221 Rev 011316.pdf', 'jan 22', 'jan 29']
#
#
# ['POLICE DETECTIVE 2223.pdf', 'WATER TREATMENT OPERATOR 5885.pdf', 'Thumbs.db', 'SHOPS SUPERINTENDENT 3780.pdf', 'LIBRARY ASSISTANT 1172.pdf', 'SENIOR BUILDING INSPECTOR 4213.pdf', 'AQUARIUM EDUCATOR 2493.pdf', 'Job summaries 01082016.pdf', 'PAINTER 3423.pdf']
#
#
# ['Job Summaries 01152016.pdf', 'Thumbs.db', 'SR CRIME & INTELLIGENCE ANALYST 2241.pdf', 'SENIOR UTILITY BUYER 1862.pdf']
#
#
# ['CIVIL ENGINEERING DRAFTING TECHNICIAN 7232.pdf', 'SENIOR ELECTRICAL REPAIR SUPERVISOR 3856.pdf', 'Thumbs.db', 'MECHANICAL ENGINEERING DRAFTING TECHNICIAN 7551.pdf', 'Job summaries 01222016.pdf', 'BUS OPERATOR SUPERVISOR 3589.pdf', 'PRINCIPAL STOREKEEPER 1839 012216.pdf']
#
#
# ['Thumbs.db', 'ASBESTOS SUPERVISOR 3440.pdf', 'X-RAY AND LABORATORY TECHNICIAN 2358.pdf', 'ENVIRONMENTAL SPECIALIST 7310.pdf', 'SENIOR LOAD DISPATCHER 5235.pdf', 'Job Summaries 01292016.pdf']
#
#
# ['aug 5 test', 'SENIOR PORT ELECTRICAL MECHANIC 3847 REV 081116.pdf', 'aug 19', 'POLICE SPECIALIST 2217 REV 080316.pdf', 'WATER UTILITY SUPERINTENDENT 3980 REV 081116.pdf', 'Thumbs.db', 'SUPERVISING TRANSPORTATION PLANNER 2481 Rev. 080416.pdf', 'POLICE SPECIAL INVESTIGATOR 1640 rev 083016.doc.pdf', 'aug 12', 'APPLICATIONS PROGRAMMER 1429 rev 083016.pdf', 'SENIOR EXAMINER OF QUESTIONED DOCUMENTS 3231 REV 080316.pdf', 'aug 26', 'aug 5', 'ELECTRICAL MECHANIC SUPERVISOR 3835 REVISED 080416.pdf', 'ENVIRONMENTAL COMPLIANCE INSPECTOR 4292 REV 081616.pdf']
#
#
# ['ENVIRONMENTAL COMPLIANCE INSPECTOR 4292 .pdf', 'Thumbs.db', 'WATER UTILITY OPERATOR 5854 .pdf', 'Job Summaries 08042016.pdf', 'WATERSHED RESOURCES SPECIALIST  7862 .pdf', 'CHIEF BUILDING OPERATING ENGINEER 5927 .pdf']
#
#
# ['Thumbs.db', 'TREE SURGEON 3114 081916.pdf', 'Job summaries 08192016.pdf', 'ELECTRICAL SERVICES MANAGER 5265 081916 .pdf']
#
#
# ['Job Summaries 08122016.pdf', 'REFUSE CREW FIELD INSTRUCTOR 4100.pdf', 'WATER SERVICES MANAGER 9602.pdf', 'Thumbs.db', 'PIPEFITTER SUPERVISOR 3438.pdf']
#
#
# ['ELECTRICAL ENGINEER 7539.pdf', 'APPLICATIONS PROGRAMMER 1429.pdf', 'POLICE SPECIAL INVESTIGATOR 1640.pdf', 'Thumbs.db', 'CONSTRUCTION AND MAINTENANCE SUPERINTENDENT 3129.pdf', 'GEOGRAPHIC INFORMATION SYSTEMS SPECIALIST 7213.pdf', 'ENVIRONMENTAL ENGINEER  7872.pdf', 'Job summaries 08262016.pdf', 'HOUSING INVESTIGATOR 8516.pdf']
#
#
# ['CHIEF BUILDING OPERATING ENGINEER 5927.pdf', 'WATER UTILITY OPERATOR 5854.pdf', 'ENVIRONMENTAL COMPLIANCE INSPECTOR 4292.pdf', 'Thumbs.db', 'WATERSHED RESOURCES SPECIALIST 7862.pdf', 'Job Summaries 08052016.pdf']
#
#
# ['dec 23', 'STREET LIGHTING ELECTRICIAN  3811 REV 122216.pdf', 'Thumbs.db', 'dec 2', 'dec 9', 'dec 16', 'UTILITY ACCOUNTANT 1511 CAMPUS REV 122016.pdf', 'HELICOPTER MECHANIC SUPERVISOR 3749 REV 122216.pdf', 'CHIEF SAFETY ENGINEER PRESSURE VESSELS 4260 REV 122016.pdf']
#
#
# ['CITY PLANNER 7944.pdf', 'STRUCTURAL STEEL FABRICATOR 3793.pdf', 'Thumbs.db', 'Job Summaries 12232016.pdf', 'HEAVY DUTY TRUCK OPERATOR 3584.pdf']
#
#
# ['PERSONNEL ANALYST 1731.pdf', 'AIRPORT MANAGER 7260.pdf', 'Thumbs.db', 'WATER BIOLOGIST 7856.pdf', 'POLICE PERFORMANCE AUDITOR 1627.pdf', 'Job Summaries 12022016.pdf']
#
#
# ['Thumbs.db', 'CHIEF SAFETY ENGINEER PRESSURE VESSELS 4260.pdf', 'CEMENT FINISHER SUPERVISOR 3354.pdf', 'STREET LIGHTING ELECTRICIAN  3811.pdf', 'PORT POLICE LIEUTENANT 3223.pdf']
#
#
# ['WASTEWATER TREATMENT OPERATOR 4123 121616.pdf', 'PORT POLICE SERGEANT 3222.pdf', 'HELICOPTER MECHANIC SUPERVISOR 3749.pdf', 'WASTEWATER COLLECTION SUPERVISOR 4113 121616.pdf', 'Job Summaries 12162016.pdf', 'Thumbs.db', 'COMMERCIAL FIELD SUPERVISOR 1603 .pdf']
#
#
# ['PORT POLICE OFFICER 3221 Rev 062416.pdf', 'jun 03', 'jun 24', 'TRANSMISSION AND DISTRIBUTION DISTRICT SUPERVISOR 3875 REVISED 063016.pdf', 'POLICE OFFICER 2214 Rev 062416.pdf', 'AIRPORT POLICE OFFICER 3225 Rev 062816.pdf', 'PORT MAINTENANCE SUPERVISOR 3128 REV 060216.pdf', 'jun 10', 'jun 17', 'FIREFIGHTER 2112 REV 060916.pdf', 'CITY PLANNING ASSOCIATE 7941 REVISED 063016.pdf']
#
#
# ['ADMINISTRATIVE ANALYST 1590.pdf', 'Thumbs.db', 'TREE SURGEON ASSISTANT 3151.pdf', 'Job summaries 06032016.pdf']
#
#
# ['EXHIBIT PREPARATOR 2444 062416.pdf', 'Thumbs.db', 'AUTOMOTIVE SUPERVISOR 3714 062416.pdf', 'POWER SHOVEL OPERATOR 3558 062416.pdf', 'FIREARMS EXAMINER 2233 062416.pdf', 'CHIEF ADMINISTRATIVE ANALYST 1554 062416.pdf', 'Job Summaries 06232016.pdf']
#
#
# ['MACHINIST 3763.pdf', 'Job 06082016.pdf', 'TRANSPORTATION INVESTIGATOR 4271.pdf']
#
#
# ['CITY PLANNING ASSOCIATE 7941.pdf', 'Thumbs.db', 'Job Summaries 06172016.pdf', 'TRANSMISSION AND DISTRIBUTION DISTRICT SUPERVISOR 3875.pdf', 'COMMERCIAL FIELD REPRESENTATIVE 1600.pdf', 'RISK MANAGER 1530.pdf']
#
#
# ['Feb 26', 'ASBESTOS SUPERVISOR 3440 REVISED 021116.pdf', 'HEAVY DUTY EQUIPMENT MECHANIC 3743 REV022516.pdf', 'Feb 19', 'ELECTRIC DISTRIBUTION MECHANIC 3879 REV022516.pdf', 'Thumbs.db', 'SENIOR ELECTRICAL REPAIR SUPERVISOR 3856 REV 020416.pdf', 'SENIOR FIRE PROTECTION ENGINEER 7981 rev022516.pdf', 'SAFETY ENGINEER PRESSURE VESSELS 4261 rev022516.pdf', 'VETERINARY TECHNICIAN 2369 Rev022516.pdf', 'WASTEWATER TREATMEN
# ['Job Summaries 02032017.pdf', 'PRINCIPAL DETENTION OFFICER 3215.pdf', 'Thumbs.db', 'ELECTRIC SERVICE REPRESENTATIVE 7520.pdf', 'SENIOR ARCHITECT 7927.pdf', 'OCCUPATIONAL HEALTH NURSE  2314.pdf', 'PERFORMING ARTS DIRECTOR 2449.pdf', 'CLAIMS AGENT 1767.pdf', 'PERSONNEL RESEARCH ANALYST 1739.pdf', 'SENIOR HOUSING INVESTIGATOR 8517.pdf']
#
#
# ['Job Summaries 02102017.pdf']
#
#
# ['WASTEWATER TREATMENT OPERATOR 4123.pdf', 'AUTO PAINTER 3721.doc.pdf', 'Thumbs.db', 'WATER UTILITY WORKER 3912.pdf', 'Job Summaries 02242017.pdf']
#
#
# ['Job Summaries 02172017.pdf', 'SAFETY ENGINEER 1727.pdf', 'HEAVY DUTY EQUIPMENT MECHANIC 3743.pdf', 'REFUSE COLLECTION TRUCK OPERATOR.pdf']
#
#
# ['Nov 17', 'Nov 3']
#
#
# ['WATER SERVICE REPRESENTATIVE 1693 111717.pdf', 'Job  11172017  Summary.pdf', 'CHIEF STREET SERVICES INVESTIGATOR 4286 2017Revised 11.21.pdf', 'MOTION PICTURE AND TELEVISION MANAGER 1789 111717.pdf', 'Job  11172017  Summary.doc', 'EQUIPMENT SPECIALIST 3734 111717 revised 11.21.pdf', 'DEPARTMENTAL CHIEF ACCOUNTANT 1593 111717 revised 11.21.pdf']
#
#
# ['ASPHALT PLANT SUPERVISOR 4145 110317.pdf', 'Job  1132017  Summary.pdf', 'OPERATIONS AND STATISTICAL RESEARCH ANALYST 1779 110317.pdf', 'CITY PLANNING ASSOCIATE 7941 110317.pdf']
#
#
# ['March 3', 'March 17', 'March 31', 'March 10', 'March 24']
#
#
# ['RISK MANAGEMENT AND PREVENTION PROGRAM SPECIALIST 7980.pdf', 'TREE SURGEON SUPERVISOR 3117.pdf', 'Thumbs.db', 'SECRETARY 1116.pdf', 'SENIOR COMMUNICATIONS ELECTRICIAN 3638.pdf', 'PUBLIC INFORMATION DIRECTOR 1800.pdf', 'Job Summaries 03032017.pdf']
#
#
# ['PRINCIPAL PUBLIC RELATIONS REPRESENTATIVE 1786.pdf', 'GEOGRAPHIC INFORMATION SYSTEMS SUPERVISOR 7214.pdf', 'Job Summaries 03172017.pdf', 'STREET LIGHTING ELECTRICIAN SUPERVISOR 3840.pdf', 'FIRE INSPECTOR 2128.pdf']
#
#
# ['MANAGEMENT AIDE 1508 033117.pdf', 'SENIOR LIBRARIAN 6153 033117.pdf', 'STEAM PLANT MAINTENANCE SUPERVISOR 3786 033117.pdf', 'Thumbs.db', 'Job 03302017.pdf', 'ASSISTANT DEPUTY SUPERINTENDENT OF BUILDING 4219 033117.pdf', 'TRAFFIC PAINTER AND SIGN POSTER 3421 033117.pdf', 'REFUSE COLLECTION SUPERVISOR 4101 033117.pdf']
#
#
# ['WORKERS COMPENSATION CLAIMS ASSISTANT 1775.pdf', 'SUPPLY SERVICES PAYMENT CLERK 1214.pdf', 'CONTRACT ADMINISTRATOR 9168.pdf', 'Thumbs.db', 'Job Summaries 03102017.pdf', 'SOLID RESOURCES SUPERINTENDENT 4102.pdf']
#
#
#
#
# ['June 16', 'June 9', 'June 2', 'June 23', 'June 30']
#
#
# ['STRUCTURAL ENGINEERING ASSOCIATE 7957 061617.pdf', 'Thumbs.db', 'CIVIL ENGINEERING ASSOCIATE 7246 061617.pdf', 'AIRPORTS MAINTENANCE SUPERVISOR 3336 061617.pdf', 'PRINCIPAL INSPECTOR 4226 061617.pdf', 'COMMERCIAL SERVICE SUPERVISOR  1213 061617.pdf', 'MECHANICAL ENGINEERING ASSOCIATE 7554 061617.pdf', 'Job 06162017.pdf']
#
#
# ['EXECUTIVE ASSISTANT AIRPORTS 9186 060917 (1).pdf', 'Job 06092017.pdf', 'Thumbs.db', 'SENIOR COMMUNICATIONS ENGINEER 7614 060917.pdf', 'BACKGROUND INVESTIGATION MANAGER 1759 060917 (2).pdf', 'STREET TREE SUPERINTENDENT 3160 060917.pdf']
#
#
# ['UTILITY ADMINISTRATOR 9105 060217.pdf', 'STRUCTURAL STEEL FABRICATOR SUPERVISOR 3794 060217.pdf', 'Thumbs.db', 'Job 06022017.pdf', 'SENIOR ELECTRICAL MECHANIC 3834 060217.pdf']
#
#
# ['DIRECTOR OF AIRPORT OPERATIONS 9304 062317 (3).pdf', 'DIRECTOR OF HOUSING 1568 062317.pdf', 'SENIOR TAX AUDITOR 1519 062317.pdf', 'Thumbs.db', 'FIRE SPRINKLER INSPECTOR 4240 062317.pdf', 'Job 06232017.pdf']
#
#
# ['Job 06292017.pdf', 'ELECTRICAL MECHANIC 3841 012017 REV 063017.pdf', 'ELECTRIC TROUBLE DISPATCHER 3828 063017 (1).pdf', 'AQUEDUCT AND RESERVOIR KEEPER 5813 063017 (1).pdf', 'ELECTRIC DISTRIBUTION MECHANIC 3879 040717 REV 063017 (1).pdf', 'AIRPORT POLICE SPECIALIST 3236 063017 (1).pdf']
#
#
# ['May 12', 'May 26', 'May 5', 'May 19']
#
#
# ['Job 05122017.pdf', 'Thumbs.db', 'LIBRARIAN 6152 051217.pdf', 'UTILITY ADMINISTRATOR 9105 051217.pdf', 'SENIOR CITY PLANNER 7947 051217.pdf', 'BACKGROUND INVESTIGATOR 1764 051217 (1).pdf', 'RECREATION FACILITY DIRECTOR 2434 051217.pdf', 'DATA PROCESSING TECHNICIAN 1136 051217.pdf']
#
#
# ['Job 05262017.pdf', 'Thumbs.db', 'GRAPHICS SUPERVISOR 7935 052617.pdf', 'TRUCK AND EQUIPMENT DISPATCHER 3586 052617.pdf', 'STREET LIGHTING ENGINEER 7537 052617.pdf']
#
#
# ['Thumbs.db', 'SENIOR RECREATION DIRECTOR 2446 050517.pdf', 'Job summaries 05052017.pdf', 'PROCUREMENT SUPERVISOR 1852 050517.pdf']
#
#
# ['COMMUNICATIONS CABLE SUPERVISOR 3800 051917 final.pdf', 'Job 05192017.pdf', 'INSTRUMENT MECHANIC SUPERVISOR 3844 051917 final.pdf']
#
#
AIRPORT GUIDE 0845 042018.txt', 'INDUSTRIAL HYGIENIST 2330 012618.txt', 'LAND SURVEYING ASSISTANT 7283 120817.txt', 'ANIMAL CARE TECHNICIAN 4310 040116 REV 041416.txt', 'LANDSCAPE ARCHITECTURAL ASSOCIATE  7933 07222016.txt', 'SENIOR TRAFFIC SUPERVISOR 3218 121517.txt', 'VIDEO TECHNICIAN 6145 012717.txt', 'ELECTRICAL REPAIRER 3853 122917 updated.txt', 'ELECTRICAL ENGINEERING ASSOCIATE 7525 093016 RE ...

# %% [markdown]
# - job bulletins :This directory contains the job bulletins in text format.
# - additional data :This directory contains additional data in pdf and csv format.

# %%
bulletins=os.listdir("../input/cityofla/CityofLA/Job Bulletins/")
additional=os.listdir("../input/cityofla/CityofLA/Additional data/")

# %% [markdown]
# We will find and print all the files inside **Additional data** that has csv format.

# %%
csvfiles=[]
for file in additional:
    if file.endswith('.csv'):
        print(file)
        csvfiles.append("../input/cityofla/CityofLA/Additional data/"+file)
# Out:
# job_titles.csv
# kaggle_data_dictionary.csv
# sample job class export template.csv

# %% [markdown]
# There are 3 comma seperated files inside the folder,
# 1. job titles : contains the title given to different jobs available.
# 2. sample job class export template.csv : contains sample job bulletin to csv export details.
# 3. kaggle_data_dictionary : contains name and description of each column that is in sample job class export template.

# %% [markdown]
# ### Reading the required csv files

# %%
job_title=pd.read_csv(csvfiles[0])
sample_job=pd.read_csv(csvfiles[1])
kaggle_data=pd.read_csv(csvfiles[2])

# %% [markdown]
# ## Getting  basic ideas[^](#0)<a id="0"></a><br>

# %% [markdown]
# In the below section we will take a look at the three csv files which was just loaded to get basic understanding of the data.

# %%
job_title.head()
# Out:
#                     311 DIRECTOR
# 0                     ACCOUNTANT
# 1               ACCOUNTING CLERK
# 2  ACCOUNTING RECORDS SUPERVISOR
# 3         ADMINISTRATIVE ANALYST
# 4           ADMINISTRATIVE CLERK

# %%
print("The are %d rows and %d cols in job_title file" %(job_title.shape))
# Out:
# The are 667 rows and 1 cols in job_title file

# %%
    sample_job[sample_job['Field Name']=='SCHOOL_TYPE']['Description']
# Out:
# 7    School Type: School type required (e.g. colleg...
# Name: Description, dtype: object

# %%
print("The are %d rows and %d cols in sample_job file" %(sample_job.shape))
# Out:
# The are 25 rows and 7 cols in sample_job file

# %%
kaggle_data.head()
# Out:
#                          FILE_NAME    ...    OPEN_DATE
# 0  SYSTEMS ANALYST 1596 102717.txt    ...     10/27/17
# 1  SYSTEMS ANALYST 1596 102717.txt    ...     10/27/17
# 2  SYSTEMS ANALYST 1596 102717.txt    ...     10/27/17
# 3  SYSTEMS ANALYST 1596 102717.txt    ...     10/27/17
# 4  SYSTEMS ANALYST 1596 102717.txt    ...     10/27/17
#
# [5 rows x 25 columns]

# %%
print("The are %d rows and %d cols in kaggle_data file" %(kaggle_data.shape))
# Out:
# The are 5 rows and 25 cols in kaggle_data file

# %%
print("There are %d text files in bulletin directory" %len(bulletins))
# Out:
# There are 683 text files in bulletin directory

# %% [markdown]
# #### Extracting the headings from job bulletins

# %%
def get_headings(bulletin):       
    
    """"function to get the headings from text file
        takes a single argument
        1.takes single argument list of bulletin files"""
    
    with open("../input/cityofla/CityofLA/Job Bulletins/"+bulletins[bulletin]) as f:    ##reading text files 
        data=f.read().replace('\t','').split('\n')
        data=[head for head in data if head.isupper()]
        return data
        
def clean_text(bulletin):      
    
    
    """function to do basic data cleaning
        takes a single argument
        1.takes single argument list of bulletin files"""
                                            
    
    with open("../input/cityofla/CityofLA/Job Bulletins/"+bulletins[bulletin]) as f:
        data=f.read().replace('\t','').replace('\n','')
        return data

# %% [markdown]
# #### Headings

# %% [markdown]
# We will print headings from first two job bulletins file.

# %%
get_headings(1)
# Out:
# ['HARBOR PLANNING AND ECONOMIC ANALYST',
#  'REVISED: 11-29-16',
#  'ANNUAL SALARY ',
#  'NOTES:',
#  'DUTIES',
#  'REQUIREMENTS/ MINIMUM QUALIFICATIONS',
#  'PROCESS NOTES',
#  'WHERE TO APPLY',
#  'NOTE:',
#  'APPLICATION DEADLINE',
#  'SELECTION PROCESS',
#  'NOTES:',
#  'THIS EXAMINATION IS TO BE GIVEN BOTH ON AN',
#  'INTERDEPARTMENTAL PROMOTIONAL AND AN OPEN COMPETITIVE BASIS',
#  'AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER']

# %%
get_headings(2)
# Out:
# ['MANAGING WATER UTILITY ENGINEER',
#  'REVISED: 04-04-17',
#  'ANNUAL SALARY   ',
#  'NOTES:',
#  'DUTIES',
#  'REQUIREMENTS/MINIMUM QUALIFICATIONS',
#  'PROCESS NOTES',
#  'WHERE TO APPLY',
#  'NOTE:',
#  'APPLICATION DEADLINE',
#  'SELECTION PROCESS',
#  'NOTES:',
#  'THIS EXAMINATION IS TO BE GIVEN ONLY',
#  ' ON AN INTERDEPARTMENTAL PROMOTIONAL BASIS',
#  'AN EQUAL EMPLOYMENT OPPORTUNITY EMPLOYER']

# %% [markdown]
# - we can observe that there is some specefic pattern or format which is kept while writing job bulletins.
# - The order of the headings almost coincides with each other,which will be beneficial for our task.

# %% [markdown]
# ## Data preparation[^](#1)<a id="1" ></a><br>

# %%
def to_dataframe(num,df):
    """"function to extract features from job bulletin text files and convert to
    pandas dataframe.
    function take two arguments 
                        1.the number of files to be read
                        2.dataframe object                                      """
    

    
    opendate=re.compile(r'(Open [D,d]ate:)(\s+)(\d\d-\d\d-\d\d)')       #match open date
    
    salary=re.compile(r'\$(\d+,\d+)((\s(to|and)\s)(\$\d+,\d+))?')       #match salary
    
    requirements=re.compile(r'(REQUIREMENTS?/\s?MINIMUM QUALIFICATIONS?)(.*)(PROCESS NOTE)')      #match requirements
    
    for no in range(0,num):
        with open("../input/cityofla/CityofLA/Job Bulletins/"+bulletins[no],encoding="ISO-8859-1") as f:         #reading files 
                try:
                    file=f.read().replace('\t','')
                    data=file.replace('\n','')
                    headings=[heading for heading in file.split('\n') if heading.isupper()]             ##getting heading from job bulletin

                    sal=re.search(salary,data)
                    date=datetime.strptime(re.search(opendate,data).group(3),'%m-%d-%y')
                    try:
                        req=re.search(requirements,data).group(2)
                    except Exception as e:
                        req=re.search('(.*)NOTES?',re.findall(r'(REQUIREMENTS?)(.*)(NOTES?)',
                                                              data)[0][1][:1200]).group(1)
                    
                    duties=re.search(r'(DUTIES)(.*)(REQ[A-Z])',data).group(2)
                    try:
                        enddate=re.search(
                                r'(JANUARY|FEBRUARY|MARCH|APRIL|MAY|JUNE|JULY|AUGUST|SEPTEMBER|OCTOBER|NOVEMBER|DECEMBER)\s(\d{1,2},\s\d{4})'
                                ,data).group()
                    except Exception as e:
                        enddate=np.nan
                    
                    selection= [z[0] for z in re.findall('([A-Z][a-z]+)((\s\.\s)+)',data)]     ##match selection criteria
                    
                    df=df.append({'File Name':bulletins[no],'Position':headings[0].lower(),'salary_start':sal.group(1),
                               'salary_end':sal.group(5),"opendate":date,"requirements":req,'duties':duties,
                                'deadline':enddate,'selection':selection},ignore_index=True)
                    
                    
                    reg=re.compile(r'(One|Two|Three|Four|Five|Six|Seven|Eight|Nine|Ten|one|two|three|four)\s(years?)\s(of\sfull(-|\s)time)')
                    df['EXPERIENCE_LENGTH']=df['requirements'].apply(lambda x :  re.search(reg,x).group(1) if re.search(reg,x) is not None  else np.nan)
                    df['FULL_TIME_PART_TIME']=df['EXPERIENCE_LENGTH'].apply(lambda x:  'FULL_TIME' if x is not np.nan else np.nan )
                    
                    reg=re.compile(r'(One|Two|Three|Four|Five|Six|Seven|Eight|Nine|Ten|one|two|three|four)(\s|-)(years?)\s(college)')
                    df['EDUCATION_YEARS']=df['requirements'].apply(lambda x :  re.search(reg,x).group(1) if re.search(reg,x) is not None  else np.nan)
                    df['SCHOOL_TYPE']=df['EDUCATION_YEARS'].apply(lambda x : 'College or University' if x is not np.nan else np.nan)
                    
                except Exception as e:
                    print('umatched sequence')
                    
                    
                
                
        
           
    return df

# %%
df=pd.DataFrame(columns=['File Name','Position','salary_start','salary_end','opendate','requirements','duties','deadline'])
df=to_dataframe(len(bulletins),df)
df.to_csv('job class output.csv')
# Out:
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence
# umatched sequence

# %%
df.shape
# Out:
# (660, 13)

# %%
df.head()
# Out:
#                                            File Name          ...                      SCHOOL_TYPE
# 0       WATER SERVICE REPRESENTATIVE 1693 111717.txt          ...                              NaN
# 1  HARBOR PLANNING AND ECONOMIC ANALYST 9224 1118...          ...            College or University
# 2  MANAGING WATER UTILITY ENGINEER 9406 032417 RE...          ...                              NaN
# 3   VETERINARY TECHNICIAN 2369 020599 REV 120417.txt          ...                              NaN
# 4  SENIOR UTILITY SERVICES SPECIALIST 3573 113018...          ...                              NaN
#
# [5 rows x 13 columns]

# %% [markdown]
# ### Preparing the data dictionary

# %%
data_dictionary=pd.DataFrame({'Field Name':['File Name','Position','salary_start','salary_end','opendate',
                                            'requirements','duties','deadline','selection','EXPERIENCE_LENGTH','FULL_TIME_PART_TIME','EDUCATION_YEARS','SCHOOL_TYPE'],
                             })

data_dictionary['Description']=['The file name of the job bulletin from which each record came','The title of the particular class (e.g., Systems Analyst, Carpenter)',
                              'The overall salary start','The overall maximum salary','The date the job bulletin opened','Overall requirement that has to be filled',
                              'A summary of what someone does in the particular job\n','The date the job bulletin closed','list of selection criterias','Years required in a particular job class or external role.',
                              'Whether the required experience is full-time, part','Years required in a particular education program',
                               'School Type: School type required (e.g. college or university, high school)']

data_dictionary['Data Type']=['string']*13

data_dictionary['Accepts Null Values?']=['Yes']*13

# %%
data_dictionary
# Out:
#              Field Name         ...          Accepts Null Values?
# 0             File Name         ...                           Yes
# 1              Position         ...                           Yes
# 2          salary_start         ...                           Yes
# 3            salary_end         ...                           Yes
# 4              opendate         ...                           Yes
# 5          requirements         ...                           Yes
# 6                duties         ...                           Yes
# 7              deadline         ...                           Yes
# 8             selection         ...                           Yes
# 9     EXPERIENCE_LENGTH         ...                           Yes
# 10  FULL_TIME_PART_TIME         ...                           Yes
# 11      EDUCATION_YEARS         ...                           Yes
# 12          SCHOOL_TYPE         ...                           Yes
#
# [13 rows x 4 columns]

# %%
data_dictionary.to_csv('data dictionary.csv')

# %% [markdown]
#  Now we have a proper comma seperataed file containing most of the information we need.we will now start exploring it.

# %% [markdown]
# Here,
# - **Position** implies JOB_CLASS_TITLE
# - **Duties** implies JOB_DUTIES
# - **Requirements** : All of the job requirements posted under requirements section
# - **Salary** has been broken down to **Salary_start** and **Salary_end** which signifies the salary range.
#     for example $ 5000 to $ 6000
#         salary_start = 5000
#         salary_end = 6000
# - **Opendate** : The job application open date
# - **deadline** : deadline for applying for the job.
# - **selection** : The list of  selection criterias.

# %% [markdown]
# ## Exploratory data analysis[^](#2)<a id="2"></a><br>

# %% [markdown]
# ### which are the common job sectors in LA?

# %%
print('There are %d different jobs available' %df['Position'].nunique())
# Out:
# There are 650 different jobs available

# %%
plt.figure(figsize=(8,5))
text=''.join(job for job in df['Position'])                                ##joining  data to form text
text=word_tokenize(text)
jobs=Counter(text)                                                         ##counting number of occurences
jobs_class=[job for job in jobs.most_common(12) if len(job[0])>3]          ##selecting most common words
#offers=[job[1] for job in jobs.most_common(12) if len(job[0]>3)]
a,b=map(list, zip(*jobs_class))
sns.barplot(b,a,palette='rocket')                                           ##creating barplot
plt.title('Job sectors')
plt.xlabel("count")
plt.ylabel('sector')
# Out:
# Text(0, 0.5, 'sector')

# %% [markdown]
# - We can see that **service sector** dominates in creating opputunities.

# %% [markdown]
# - It might be a good idea to have **different display boards** for service and product sectors,so that candidates can easily find job of their preference.

# %%
""""
    convert salary to proper  form 
    by removing '$' and ',' symbols.
                                    """

df['salary_start']=[int(sal.split(',')[0]+sal.split(',')[1] ) for sal in df['salary_start']]   
df['salary_end']=[sal.replace('$','')  if sal!= None else 0 for sal in df['salary_end']  ]
df['salary_end']=[int(sal.split(',')[0]+sal.split(',')[1] ) if type(sal)!=int else 0 for sal in df['salary_end']]

# %% [markdown]
# ### What about the salary distribution?

# %%
plt.figure(figsize=(7,5))
sns.distplot(df['salary_start'])
plt.title('salary distribution')
plt.show()

# %% [markdown]
# - we can observe that thet salaries typically varies from $50k to $150k.
# - Most jobs salary start from $80000.

# %% [markdown]
# ### Which are the best paid jobs in LA?

# %%
'''finding the most paid 10 jobs at LA'''

most_paid=df[['Position','salary_start']].sort_values(by='salary_start',ascending=False)[:10]
plt.figure(figsize=(7,5))
sns.barplot(y=most_paid['Position'],x=most_paid['salary_start'],palette='rocket')
plt.title('Best paid jobs in LA')
# Out:
# Text(0.5, 1.0, 'Best paid jobs in LA')

# %% [markdown]
# ### Which the jobs with highest salary deviation?

# %%
''''calculating salary start - salary end '''

df['salary_diff']=abs(df['salary_start']-df['salary_end'])

ranges=df[['Position','salary_diff']].sort_values(by='salary_diff',ascending=False)[:10]

# %%
plt.figure(figsize=(7,5))
sns.barplot(y=ranges['Position'],x=ranges['salary_diff'],palette='RdBu')   ##plotting

# %%
ranges
# Out:
#                                      Position  salary_diff
# 597      mechanical repair general supervisor       121166
# 129  building maintenance district supervisor       121166
# 599        chief building operating engineer        119997
# 300       port electrical mechanic supervisor       119172
# 71             instrument mechanic supervisor       119036
# 430  wastewater treatment mechanic supervisor       118843
# 496             general automotive supervisor       118577
# 312   construction and maintenance supervisor       114485
# 589      senior wastewater treatment operator       114234
# 137           senior port electrical mechanic       112955

# %% [markdown]
# ### Has job opportunities really increased recently?

# %%
'''Extracting year out of opendate timestamp object and counting
    the number of each occurence of each year using count_values() '''

df['year_of_open']=[date.year for date in df['opendate']]

count=df['year_of_open'].value_counts(ascending=True)
years=['2020','2019','2018', '2017', '2016', '2015', '2014', '2013', '2012', '2008', '2006',
           '2005', '2002', '1999']
plt.figure(figsize=(7,5))
plt.plot([z for z in reversed(years)],count.values,color='blue')

plt.title('Oppurtunities over years')
plt.xlabel('years')
plt.ylabel('count')
plt.gca().set_xticklabels([z for z in reversed(years)],rotation='45')
plt.show()

# %% [markdown]
# - It is evident from the above graph that job oppurtunities is constantly increasing after 2012 or so.
# - job oppurtunities has never decreased.

# %% [markdown]
# ### What about the full time experience?

# %%
experience=df['EXPERIENCE_LENGTH'].value_counts().reset_index()
experience['index']=experience['index'].apply(lambda x : x.lower())
experience=experience.groupby('index',as_index=False).agg('sum')
labels=experience['index']
sizes=experience['EXPERIENCE_LENGTH']
plt.figure(figsize=(5,7))
plt.pie(sizes,explode=(0, 0.1, 0, 0,0,0,0),labels=labels)
plt.gca().axis('equal')
plt.title('Experience value count')
plt.show()

# %% [markdown]
# - I think it is clear that 50 percent of the job requires atleat two years experience in the field.
# - This has a negative effect of keeping freshers away from entering the job sector.

# %% [markdown]
# ### Experience or College degree, which is more preferred ?

# %%
x1=df['SCHOOL_TYPE'].value_counts()[0]
x2=df['FULL_TIME_PART_TIME'].value_counts()[0]
plt.figure(figsize=(5,5))
plt.bar(height=[x1,x2],x=['College Degree','Experience'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# - Almost all jobs bulletins specify the experience needed by candidate to qualify for the job.
#   But only some post the required educational baground.This might be in the assumption that an experienced candidate will surely posses College or university degree.

# %% [markdown]
# ### Which month of the year offers most opportunities?

# %%
'''Extracting month out of opendate timestamp object and counting
    the number of each occurence of each months using count_values() '''


plt.figure(figsize=(7,5))
df['open_month']=[z.month for z in df['opendate']]
count=df['open_month'].value_counts(sort=False)
sns.barplot(y=count.values,x=count.index,palette='rocket')
plt.gca().set_xticklabels([calendar.month_name[x] for x in count.index],rotation='45')
plt.show()

# %% [markdown]
# We can see that there is more job opportunities created in the months of **March,October and December**

# %% [markdown]
# *** - It  might be a good idea to declare these months as **hiring months** and this could even attract a lot of potential candidates.

# %% [markdown]
# ### Which day of the week ?

# %%
'''Extracting weekday out of opendate timestamp object and counting
    the number of each occurence of each weekday using count_values() '''


plt.figure(figsize=(7,5))

df['open_day']=[z.weekday() for z in df['opendate']]
count=df['open_day'].value_counts(sort=False)
sns.barplot(y=count.values,x=count.index,palette='rocket')
plt.gca().set_xticklabels([calendar.day_name[x] for x in count.index],rotation='45')
plt.show()

# %% [markdown]
# Wow ! All the postings are open from **friday** ! This is pretty interesting.
# - Is there any specific reason behind this?
# We will try to find out.
# anyway its good to post all opening in a day  of week so  that candidates can refer the bulletins and apply without missing any openings.

# %% [markdown]
# ### what about deadlines ?

# %%
print('%d job applications may close without prior notice' %df['deadline'].isna().sum())
# Out:
# 44 job applications may close without prior notice

# %% [markdown]
# - I think employers should post a deadline for job application in the job bulletins to avoid any unwanted confusions between candidates.

# %%
#df['dealine']=df['deadline'].fillna(method='backfill',inplace=True
#deadline=[datetime.strptime(x,'%B %d, %Y')  for x in df['deadline'] ]

# %%
req=' '.join(text for text in df['requirements'])

# %% [markdown]
# ### Word Cloud of Requirements

# %%
def show_wordcloud(data, title = None):
    
    
    '''funtion to produce and display wordcloud
        taken 2 arguments
        1.data to produce wordcloud
        2.title of wordcloud'''
    
    
    wordcloud = WordCloud(
        background_color='white',
        stopwords=set(STOPWORDS),
        max_words=250,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
show_wordcloud(text,'REQUIREMENTS')

# %% [markdown]
# ### Most influential words in requirements

# %%
lem=WordNetLemmatizer()
text=[lem.lemmatize(w) for w in word_tokenize(req)]
vect=TfidfVectorizer(ngram_range=(1,3),max_features=100)
vectorized_data=vect.fit_transform(text)
#id_map=dict((v,k) for k,v in vect.vocabulary_.items())
vect.vocabulary_.keys()
# Out:
# dict_keys(['three', 'year', 'of', 'full', 'time', 'full time', 'paid', 'experience', 'in', 'class', 'at', 'the', 'level', 'service', 'performing', 'public', 'work', 'water', 'related', 'and', 'from', 'or', 'to', 'an', 'accredited', 'college', 'university', 'may', 'be', 'substituted', 'on', 'for', 'two', 'required', 'one', 'is', 'semester', 'quarter', 'unit', 'graduation', 'four', 'four year', 'and2', 'professional', 'planning', 'analysis', 'engineer', 'system', 'department', 'engineering', 'design', 'construction', 'operation', 'maintenance', 'with', 'california', 'certificate', 'by', 'state', 'city', 'los', 'angeles', 'position', 'that', 'which', 'provides', 'building', 'management', 'and or', 'program', 'completion', 'recognized', 'must', 'or2', 'six', 'degree', 'including', 'following', 'or3', 'month', 'valid', 'supervisor', 'least', 'course', 'senior', 'environmental', 'mechanical', 'repair', 'equipment', 'administration', 'school', 'requirement', 'supervising', 'training', 'field', 'science', 'such', 'electrical', 'line', 'on line'])

# %% [markdown]
# ### Word 2 Vec

# %%
def build_corpus(df,col):
    
    '''function to build corpus from dataframe'''
    lem=WordNetLemmatizer()
    corpus= []
    for x in df[col]:
        
        
        words=word_tokenize(x)
        corpus.append([lem.lemmatize(w) for w in words])
    return corpus

# %%
corpus=build_corpus(df,'requirements')
model = word2vec.Word2Vec(corpus, size=100, window=20, min_count=30, workers=4)

# %% [markdown]
# ### TSNE

# %%
def tsne_plot(model,title='None'):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []

    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
    
    tsne_model = TSNE(perplexity=80, n_components=2, init='pca', n_iter=2500, random_state=23)
    new_values = tsne_model.fit_transform(tokens)

    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(12, 12)) 
    plt.title(title)
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
                     xy=(x[i], y[i]),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()

# %%
tsne_plot(model,'Requirements')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %% [markdown]
# - we can see clusters of words used in **Requirement** section.

# %% [markdown]
# ### What are the common requirements for any post?

# %%
token=word_tokenize(req)
counter=Counter(token)
count=[x[0] for x in counter.most_common(40) if len(x[0])>3]
print("Most common words in Requirement")
print(count)
# Out:
# Most common words in Requirement
# ['experience', 'paid', 'full-time', 'years', 'with', 'City', 'Angeles', 'level', 'from', 'year', 'college', 'accredited', 'university', 'class', 'professional', 'maintenance', 'which', 'units']

# %% [markdown]
# - It can be observed that companies prefer
# - **experienced**
# - **educated professionals**  having **degree from an accredicted university**
# - also willing to work **full-time**

# %% [markdown]
# - To improve the diversity employers are encourged to give chance to **Freshers** and people willing to work **part time**.
#      This can attract greater pool of applicants.

# %% [markdown]
# ### Duties

# %%
duties= ' '.join(d for d in df['duties'])
show_wordcloud(duties,'Duties')

# %% [markdown]
# ### Most influential and common words in duties

# %%
lem=WordNetLemmatizer()
text=[lem.lemmatize(w) for w in word_tokenize(duties)]
vect=TfidfVectorizer(ngram_range=(1,3),max_features=200)
vectorized_data=vect.fit_transform(text)
#id_map=dict((v,k) for k,v in vect.vocabulary_.items())
vect.vocabulary_.keys()
# Out:
# dict_keys(['water', 'service', 'make', 'field', 'investigation', 'to', 'and', 'with', 'customer', 'or', 'their', 'in', 'the', 'office', 'on', 'issue', 'for', 'planning', 'performs', 'administrative', 'technical', 'work', 'maintaining', 'port', 'plan', 'city', 'prepares', 'development', 'other', 'evaluates', 'process', 'conduct', 'transportation', 'related', 'research', 'facility', 'engineer', 'may', 'director', 'assistant', 'of', 'division', 'manager', 'major', 'project', 'system', 'department', 'power', 'an', 'general', 'senior', 'difficult', 'responsible', 'professional', 'engineering', 'preparation', 'design', 'specification', 'contract', 'study', 'treatment', 'report', 'procedure', 'various', 'distribution', 'operation', 'maintenance', 'activity', 'including', 'compliance', 'safety', 'program', 'develops', 'policy', 'applies', 'sound', 'management', 'supervisory', 'principle', 'technique', 'building', 'effective', 'workforce', 'fulfills', 'equal', 'employment', 'opportunity', 'responsibility', 'assist', 'by', 'performing', 'duty', 'animal', 'at', 'doe', 'be', 'assigned', 'required', 'services', 'assigns', 'review', 'employee', 'engaged', 'use', 'electric', 'support', 'manages', 'large', 'force', 'worker', 'variety', 'repair', 'equipment', 'supervises', 'such', 'is', 'from', 'are', 'mechanical', 'public', 'information', 'community', 'through', 'skilled', 'act', 'lead', 'crew', 'group', 'construction', 'organizes', 'directs', 'subordinate', 'supervisor', 'training', 'financial', 'accounting', 'record', 'control', 'wastewater', 'operating', 'coordinate', 'installation', 'high', 'level', 'electrical', 'maintains', 'chief', 'staff', 'clerical', 'administration', 'and or', 'personnel', 'provides', 'operates', 'communication', 'station', 'computer', 'operator', 'environmental', 'parking', 'directing', 'street', 'area', 'meter', 'data', 'collection', 'inspects', 'all', 'officer', 'airport', 'security', 'state', 'law', 'analysis', 'police', 'supervise', 'processing', 'wide', 'traffic', 'regulation', 'unit', 'property', 'testing', 'more', 'park', 'position', 'enforcement', 'test', 'los', 'angeles', 'inspection', 'material', 'which', 'plant', 'agency', 'line', 'care', 'fire', 'cable', 'drafting'])

# %%
token=word_tokenize(duties)
counter=Counter(token)
count=[x[0] for x in counter.most_common(40) if len(x[0])>3]
print("Most common words in Duties")
print(count)
# Out:
# Most common words in Duties
# ['work', 'maintaining', 'building', 'techniques', 'applies', 'supervisory', 'sound', 'effective', 'principles', 'responsibilities', 'fulfills', 'employment', 'equal', 'opportunity', 'engaged', 'force', 'related', 'City', 'equipment', 'performs', 'plans', 'other', 'with', 'maintenance', 'employees']

# %% [markdown]
# ### Word 2 Vec

# %%
corpus=build_corpus(df,'duties')
model = word2vec.Word2Vec(corpus, size=100, window=20, min_count=40, workers=4)

# %% [markdown]
# ### TSNE

# %%
tsne_plot(model,'Duties')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys

# %% [markdown]
# ###  Latent Dirichlet Allocation (LDA)

# %% [markdown]
# Topic modeling is a type of statistical modeling for discovering the abstract “topics” that occur in a collection of documents. Latent Dirichlet Allocation (LDA) is an example of topic model and is used to classify text in a document to a particular topic. It builds a topic per document model and words per topic model, modeled as Dirichlet distributions.

# %%
lem=WordNetLemmatizer()
text=[lem.lemmatize(w) for w in word_tokenize(duties)]
vect=TfidfVectorizer(ngram_range=(1,3),max_features=200)
vectorized_data=vect.fit_transform(text)
id2word=dict((v,k) for k,v in vect.vocabulary_.items())

# %%
corpus=gensim.matutils.Sparse2Corpus(vectorized_data,documents_columns=False)
ldamodel = gensim.models.ldamodel.LdaModel(corpus,id2word=id2word,num_topics=8,random_state=34,passes=25,per_word_topics=True)

# %%
ldamodel.show_topic(1)

# %% [markdown]
# ###  What is the Dominant topic and its percentage contribution in each document

# %% [markdown]
# In LDA models, each document is composed of multiple topics. But, typically only one of the topics is dominant. The below code extracts this dominant topic for each sentence and shows the weight of the topic and the keywords in a nicely formatted output.

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row_list in enumerate(ldamodel[corpus]):
        row = row_list[0] if ldamodel.per_word_topics else row_list            
        # print(row)
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=ldamodel, corpus=corpus, texts=build_corpus(df,'duties'))

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.dropna(inplace=True)
df_dominant_topic.head(5)

# %% [markdown]
# ### Topic modeling visualization

# %%
data=build_corpus(df,'duties')

# %% [markdown]
# ### Word Counts of Topic Keywords

# %% [markdown]
# When it comes to the keywords in the topics, the importance (weights) of the keywords matters. Along with that, how frequently the words have appeared in the documents is also interesting to look.
#
# Let’s plot the word counts and the weights of each keyword in the same chart.
#
# You want to keep an eye out on the words that occur in multiple topics and the ones whose relative frequency is more than the weight. Often such words turn out to be less important. The chart I’ve drawn below is a result of adding several such words to the stop words list in the beginning and re-running the training process.

# %%
topics = ldamodel.show_topics(formatted=False)
data_flat = [w for w_list in build_corpus(df,'duties') for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df_plot= pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(4, 2, figsize=(10,12), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df_plot.loc[df_plot.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df_plot.loc[df_plot.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    #ax_twin.set_ylim(0, 0.040); ax.set_ylim(0, 4000)
    ax.set_title('Topic: ' + str(i), color=cols[i])
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df_plot.loc[df_plot.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords',y=1)    
plt.show()

# %% [markdown]
# ### What are the most common selection criterias?

# %%
plt.figure(figsize=(7,7))
count=df['selection'].astype(str).value_counts()[:10]
sns.barplot(y=count.index,x=count,palette='rocket')
plt.gca().set_yticklabels(count.index,rotation='45')
plt.show()

# %% [markdown]
# - It is evident that  **interview** ,**Essay** and **Questionnaire** are the most common selection criterias.

# %% [markdown]
# ### Suggestions[](#3)<a id='3'></a><br>

# %% [markdown]
# 1. It might be a good idea to have **different display boards** for service and product sectors,so that candidates can easily find job of their preference.
# 2. 50 percent of the job requires atleat two years experience in the field.This has a negative effect of keeping freshers away from entering the job sector.
# 3. It  might be a good idea to declare March,October,December months as **hiring months** and this could even attract a lot of potential candidates.
# 4. Define a deadline to avoid confusions and delaying.(2weeks is ideal)

# %% [markdown]
# ## Finding and removing gender biases[^](#4)<a id="3"></a><br>

# %% [markdown]
# ### Is there any Gender bias in job bulletins?

# %% [markdown]
# In the follow section i am trying investigate if there is any gender biased terms used in **Requirement** and **Duties** section of the job bulletin.
# For that i will pos tag all the text data in the requirement field and then,
# - Extract the words having pronoun tag.
# - check if any gender biased terms like he/she is used in the field.

# %%
def pronoun(data):
    
    '''function to tokenize data and perform pos_tagging.Returns tokens having "PRP" tag'''
    
    prn=[]
    vrb=[]
    token=word_tokenize(data)
    pos=pos_tag(token)
   
    vrb=Counter([x[0] for x in pos if x[1]=='PRP'])
    
    return vrb
    


req_prn=pronoun(req)
duties_prn=pronoun(duties)
print('pronouns used in requirement section are')
print(req_prn.keys())
print('\npronouns used in duties section are')
print(duties_prn.keys())

# %% [markdown]
# 1. Surprisingly, i couldn't find any gender biased or racist pronouns in **Requirement ** or **Duties section**
# 2. you can see all the pronouns used are neutral.

# %% [markdown]
# ###  Is there any gender bias in job titles?

# %% [markdown]
# - In this section we will try and find out if there is any gender bias in job titles.
#     A **gender-specific job title** is a name of a job that also specifies or implies the gender of the person performing that job.
#     the job title **policeman** implies that the person is male. A gender-neutral job title, on the other hand, is one that does not specify or imply       gender, such as firefighter or a lawyer.

# %%
names=['senior waterman','policeman']
for name in names:
    z=re.match(r'\w+?\s?\w+(man|women)$',name)
    print(z)

# %% [markdown]
# - So you can see that the code works well.We will try in our dataset.

# %%
for name in df['Position']:
    z=re.match(r'\w+?\s?\w+(man|women)$',name)
    if z is not None:
        print(z)

# %% [markdown]
# - Nothing ! I think the authorities hava done a good job by removing possible gender biases from job titles and renamed it suitably.

# %% [markdown]
# ## Clustering Jobs [^](#5)<a id="4"></a><br>

# %% [markdown]
# ### Finding similar jobs

# %% [markdown]
# Here in this section I am trying to find similar jobs given a job title.
# - **Assumption** : I assume that similar jobs have similar job title.
#
# I have used jaccard distance to find the text similarity and compare it with a threashold value to obtain the jobs.
# This method can output the jobs the same domain so that candidates who posses the right skills can apply for similar jobs in the domain.I believe clustering jobs can improve the pool of applicants to great extend.

# %%
def similar_jobs(job):
    
    ''' function to find and return jobs with similar job title.take a single argument
            - job title
            returns
                -list of similar jobs '''
    
    word1=word_tokenize(job)
    jobs=[]
    for i,name in enumerate(df['Position']):
        word2=word_tokenize(name)
        distance=jaccard_distance(set(ngrams(word1,n=1)),set(ngrams(word2,n=1)))
        if(distance<.55):
            jobs.append((name,i))
    return jobs

# %%
similar_jobs(df['Position'][10])

# %% [markdown]
# - you can clearly observe that the jobs outputted are from the same domain and are moreover similar.

# %% [markdown]
# ### Finding jobs with similar requirements

# %%
def similar_req(job):
    
    ''' function to find and return jobs with similar job title.take a single argument
            - job title
            returns
                -list of similar jobs '''
    
    word1=word_tokenize(job)
    jobs=[]
    for i,name in enumerate(df['requirements']):
        word2=word_tokenize(name)
        distance=jaccard_distance(set(ngrams(word1,n=1)),set(ngrams(word2,n=1)))
        if(distance<.5):
            jobs.append((name,df.iloc[i]['Position']))
    return jobs

# %%
similar_req(df['requirements'][10])

# %%
df['requirements'][312]

# %% [markdown]
# - City of LA can use any of the similarity functions available to find jobs having similar requirements,for example jaccard distace,cosine similary etc..I have implemented jaccard similarity the in above section.

# %% [markdown]
# ## Readability Index[^](#6)<a id="5"></a><br>

# %% [markdown]
# - FleschKincaid Grade Level
# Designed to indicate how difficult a reading passage is to understand. The result is a number that corresponds with a U.S grade level.
# > FKGL = 0.39 * (total words/ total
# sentences) + 11.8 (total syllables/
# total words) -15.59

# %% [markdown]
# **Flesch Index  -------         Text file reading Grade**
#
#    0-30      ---------              College
#
#    50-60     ---------               High School
#
#    90-100    ---------                Fourth Grade
#
#
# 1. From above the flesch-kincaid Grade level formula is used to compute the equivalent Grade level G −

# %%
reading=[]
for file in df['File Name']:
    text=open("../input/cityofla/CityofLA/Job Bulletins/"+file,'r',encoding="ISO-8859-1").read()
    sentence = text.count('.') + text.count('!') + text.count(';') + text.count(':') + text.count('?')
    words = len(text.split())
    syllable = 0
    for word in text.split():
        for vowel in ['a','e','i','o','u']:
            syllable += word.count(vowel)
        for ending in ['es','ed','e']:
            if word.endswith(ending):
                   syllable -= 1
        if word.endswith('le'):
            syllable += 1
            
    G = round((0.39*words)/sentence+ (11.8*syllable)/words-15.59)
    reading.append(G)

# %% [markdown]
# - Plotting Grade level distribution

# %%
plt.hist(reading)
plt.xlabel('Flesch Index')
plt.title('Flesch index distribution')
plt.show()

# %% [markdown]
# - we can see that index is always between 0-30,which comes under college grade.May be city of LA officials should look in to this and moderate their bulletins to make it simple to read !

# %% [markdown]
# ### If you like my kernel please consider upvoting.Thank you :)
